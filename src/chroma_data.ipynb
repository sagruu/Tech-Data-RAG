# %% [markdown]
# ## Evaluierung ChromaDB

# %% [markdown]
# In diesem Notebook werden die verschiedenene Parameter von ChromaDB gelistet. Dabei werden verschiedene Datenbänke erstellt und miteinenader verglichen.

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.text_splitter import SentenceTransformersTokenTextSplitter
from Chroma_Embedding_Pipeline import ChromaEmbeddingPipeline
from chromadb.api.client import SharedSystemClient
from langchain.embeddings import AzureOpenAIEmbeddings
import chromadb
import pandas as pd
import os
from dotenv import load_dotenv
load_dotenv()
from itertools import product

# %%
# Credentials loaded from .env via dotenv
# os.environ variables set in .env file
os.environ["AZURE_OPENAI_API_VERSION"] = "2023-05-15"

# %%
# Bereinigte Daten einlesen
df_train_cleaned = pd.read_parquet('../data_mc1/data_processed/df_train_1000.parquet')

# %%
df_train_cleaned.head()
# Out:
#       id                                              title       date  \
# 0  93950    Agrivoltaics Goes Nuclear On California Prairie 2022-12-18
# 1  93986  The Wait For Hydrogen Fuel Cell Electric Aircr... 2023-01-02
# 2  21630  Quality Control System for Ocean Temperature I... 2023-01-30
# 3  98795  European Commission introduces Green Deal Indu... 2023-02-02
# 4  21739  More Mild Winters with Erratic Temperature Cha... 2023-03-01
#
#           domain                                                url language  \
# 0  cleantechnica  https://cleantechnica.com/2022/12/18/agrivolta...       en
# 1  cleantechnica  https://cleantechnica.com/2023/01/02/the-wait-...       en
# 2   azocleantech  https://www.azocleantech.com/news.aspx?newsID=...       en
# 3    pv-magazine  https://www.pv-magazine.com/2023/02/02/europea...       en
# 4   azocleantech  https://www.azocleantech.com/news.aspx?newsID=...       en
#
#                                              content
# 0  Agrivoltaics Goes Nuclear On California Prairi...
# 1  The Wait For Hydrogen Fuel Cell Electric Aircr...
# 2  Quality Control System for Ocean Temperature I...
# 3  European Commission introduces Green Deal Indu...
# 4  More Mild Winters with Erratic Temperature Cha...

# %%
embedding_models = [
    "text-embedding-ada-002",
    "text-embedding-3-large"
]

base_configs = [
    {
        "splitter_type": "RecursiveCharacterTextSplitter",
        "chunk_size": 800,
        "chunk_overlap": 100,
        "separators": ["\n\n", "\n", ".", " ", ""],
        "hnsw:space": "cosine",
        "collection_name": "recchar_800_cosine",
        "persist_directory": "./chroma_recchar_800_cosine"
    },
    {
        "splitter_type": "RecursiveCharacterTextSplitter",
        "chunk_size": 800,
        "chunk_overlap": 100,
        "separators": ["\n\n", "\n", ".", " ", ""],
        "hnsw:space": "l2",
        "collection_name": "recchar_800_l2",
        "persist_directory": "./chroma_recchar_800_l2"
    },
    {
        "splitter_type": "RecursiveCharacterTextSplitter",
        "chunk_size": 800,
        "chunk_overlap": 100,
        "separators": ["\n\n", "\n", ".", " ", ""],
        "hnsw:space": "ip",
        "collection_name": "recchar_800_ip",
        "persist_directory": "./chroma_recchar_800_ip"
    },
    {
        "splitter_type": "SentenceTransformersTokenTextSplitter",
        "chunk_size": 200,
        "chunk_overlap": 20,
        "model_name": "sentence-transformers/all-MiniLM-L6-v2",
        "hnsw:space": "cosine",
        "collection_name": "senttrans_200_cosine",
        "persist_directory": "./chroma_senttrans_200_cosine"
    },
    {
        "splitter_type": "SentenceTransformersTokenTextSplitter",
        "chunk_size": 200,
        "chunk_overlap": 20,
        "model_name": "sentence-transformers/all-MiniLM-L6-v2",
        "hnsw:space": "l2",
        "collection_name": "senttrans_200_l2",
        "persist_directory": "./chroma_senttrans_200_l2"
    },
    {
        "splitter_type": "SentenceTransformersTokenTextSplitter",
        "chunk_size": 200,
        "chunk_overlap": 20,
        "model_name": "sentence-transformers/all-MiniLM-L6-v2",
        "hnsw:space": "ip",
        "collection_name": "senttrans_200_ip",
        "persist_directory": "./chroma_senttrans_200_ip"
    }
]

# Gemeinsame Metadaten- und Pipeline-Parameter
metadata_config_base = {
    "hnsw:M": 16,
    "efConstruction": 200
}
pipeline_params = {
    "deployment_name": "text-embedding-3-large",
    "batch_size": 20,
    "sleep_time": 1.0
}

all_configs = []
for base in base_configs:
    for model in embedding_models:
        new_config = base.copy()
        new_config["deployment_name"] = model
        new_config["collection_name"] = f"{base['collection_name']}_{model.replace('text-embedding-', '')}"
        new_config["persist_directory"] = f"{base['persist_directory']}_{model.replace('text-embedding-', '')}"
        all_configs.append(new_config)

vector_stores = []

for config in all_configs:
    print(f"Processing config: {config['collection_name']}")
    
    SharedSystemClient.clear_system_cache()  # falls verwendet

    # TextSplitter erstellen
    if config["splitter_type"] == "RecursiveCharacterTextSplitter":
        splitter = RecursiveCharacterTextSplitter(
            chunk_size=config["chunk_size"],
            chunk_overlap=config["chunk_overlap"],
            separators=config["separators"]
        )
    else:
        splitter = SentenceTransformersTokenTextSplitter(
            chunk_size=config["chunk_size"],
            chunk_overlap=config["chunk_overlap"],
            model_name=config["model_name"]
        )

    metadata_config = metadata_config_base.copy()
    metadata_config["hnsw:space"] = config["hnsw:space"]

    chroma_settings = chromadb.Settings(
        allow_reset=True,
        is_persistent=True,
        persist_directory=config["persist_directory"],
        anonymized_telemetry=False
    )

    pipeline = ChromaEmbeddingPipeline(
        df=df_train_cleaned,
        text_column="content",
        deployment_name=config["deployment_name"],
        splitter=splitter,
        collection_name=config["collection_name"],
        persist_directory=config["persist_directory"],
        metadata=metadata_config,
        batch_size=pipeline_params["batch_size"],
        sleep_time=pipeline_params["sleep_time"],
        chroma_settings=chroma_settings
    )

    vector_store = pipeline.run()
    vector_stores.append(vector_store)

    print(f"Created DB: {config['collection_name']}")
# Out:
# Processing config: recchar_800_cosine_ada-002
# 6394 Chunks erzeugt.
# /Users/husazwerg/code/gitlab.fhnw.ch/gruppen_arbeit/npr_fs25/MC1/src/Chroma_Embedding_Pipeline.py:146: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   vector_store = Chroma(
# Batch 1: 20 Chunks hinzugefügt
# Batch 2: 20 Chunks hinzugefügt
# Batch 3: 20 Chunks hinzugefügt
# Batch 4: 20 Chunks hinzugefügt
# Batch 5: 20 Chunks hinzugefügt
# Batch 6: 20 Chunks hinzugefügt
# Batch 7: 20 Chunks hinzugefügt
# Batch 8: 20 Chunks hinzugefügt
# Batch 9: 20 Chunks hinzugefügt
# Batch 10: 20 Chunks hinzugefügt
# Batch 11: 20 Chunks hinzugefügt
# Batch 12: 20 Chunks hinzugefügt
# Batch 13: 20 Chunks hinzugefügt
# Batch 14: 20 Chunks hinzugefügt
# Batch 15: 20 Chunks hinzugefügt
# Batch 16: 20 Chunks hinzugefügt
# Batch 17: 20 Chunks hinzugefügt
# Batch 18: 20 Chunks hinzugefügt
# Batch 19: 20 Chunks hinzugefügt
# Batch 20: 20 Chunks hinzugefügt
# Batch 21: 20 Chunks hinzugefügt
# Batch 22: 20 Chunks hinzugefügt
# Batch 23: 20 Chunks hinzugefügt
# Batch 24: 20 Chunks hinzugefügt
# Batch 25: 20 Chunks hinzugefügt
# Batch 26: 20 Chunks hinzugefügt
# Batch 27: 20 Chunks hinzugefügt
# Batch 28: 20 Chunks hinzugefügt
# Batch 29: 20 Chunks hinzugefügt
# Batch 30: 20 Chunks hinzugefügt
# Batch 31: 20 Chunks hinzugefügt
# Batch 32: 20 Chunks hinzugefügt
# Batch 33: 20 Chunks hinzugefügt
# Batch 34: 20 Chunks hinzugefügt
# Batch 35: 20 Chunks hinzugefügt
# Batch 36: 20 Chunks hinzugefügt
# Batch 37: 20 Chunks hinzugefügt
# Batch 38: 20 Chunks hinzugefügt
# Batch 39: 20 Chunks hinzugefügt
# Batch 40: 20 Chunks hinzugefügt
# Batch 41: 20 Chunks hinzugefügt
# Batch 42: 20 Chunks hinzugefügt
# Batch 43: 20 Chunks hinzugefügt
# Batch 44: 20 Chunks hinzugefügt
# Batch 45: 20 Chunks hinzugefügt
# Batch 46: 20 Chunks hinzugefügt
# Batch 47: 20 Chunks hinzugefügt
# Batch 48: 20 Chunks hinzugefügt
# Batch 49: 20 Chunks hinzugefügt
# Batch 50: 20 Chunks hinzugefügt
# Batch 51: 20 Chunks hinzugefügt
# Batch 52: 20 Chunks hinzugefügt
# Batch 53: 20 Chunks hinzugefügt
# Batch 54: 20 Chunks hinzugefügt
# Batch 55: 20 Chunks hinzugefügt
# Batch 56: 20 Chunks hinzugefügt
# Batch 57: 20 Chunks hinzugefügt
# Batch 58: 20 Chunks hinzugefügt
# Batch 59: 20 Chunks hinzugefügt
# Batch 60: 20 Chunks hinzugefügt
# Batch 61: 20 Chunks hinzugefügt
# Batch 62: 20 Chunks hinzugefügt
# Batch 63: 20 Chunks hinzugefügt
# Batch 64: 20 Chunks hinzugefügt
# Batch 65: 20 Chunks hinzugefügt
# Batch 66: 20 Chunks hinzugefügt
# Batch 67: 20 Chunks hinzugefügt
# Batch 68: 20 Chunks hinzugefügt
# Batch 69: 20 Chunks hinzugefügt
# Batch 70: 20 Chunks hinzugefügt
# Batch 71: 20 Chunks hinzugefügt
# Batch 72: 20 Chunks hinzugefügt
# Batch 73: 20 Chunks hinzugefügt
# Batch 74: 20 Chunks hinzugefügt
# Batch 75: 20 Chunks hinzugefügt
# Batch 76: 20 Chunks hinzugefügt
# Batch 77: 20 Chunks hinzugefügt
# Batch 78: 20 Chunks hinzugefügt
# Batch 79: 20 Chunks hinzugefügt
# Batch 80: 20 Chunks hinzugefügt
# Batch 81: 20 Chunks hinzugefügt
# Batch 82: 20 Chunks hinzugefügt
# Batch 83: 20 Chunks hinzugefügt
# Batch 84: 20 Chunks hinzugefügt
# Batch 85: 20 Chunks hinzugefügt
# Batch 86: 20 Chunks hinzugefügt
# Batch 87: 20 Chunks hinzugefügt
# Batch 88: 20 Chunks hinzugefügt
# Batch 89: 20 Chunks hinzugefügt
# Batch 90: 20 Chunks hinzugefügt
# Batch 91: 20 Chunks hinzugefügt
# Batch 92: 20 Chunks hinzugefügt
# Batch 93: 20 Chunks hinzugefügt
# Batch 94: 20 Chunks hinzugefügt
# Batch 95: 20 Chunks hinzugefügt
# Batch 96: 20 Chunks hinzugefügt
# Batch 97: 20 Chunks hinzugefügt
# Batch 98: 20 Chunks hinzugefügt
# Batch 99: 20 Chunks hinzugefügt
# Batch 100: 20 Chunks hinzugefügt
# Batch 101: 20 Chunks hinzugefügt
# Batch 102: 20 Chunks hinzugefügt
# Batch 103: 20 Chunks hinzugefügt
# Batch 104: 20 Chunks hinzugefügt
# Batch 105: 20 Chunks hinzugefügt
# Batch 106: 20 Chunks hinzugefügt
# Batch 107: 20 Chunks hinzugefügt
# Batch 108: 20 Chunks hinzugefügt
# Batch 109: 20 Chunks hinzugefügt
# Batch 110: 20 Chunks hinzugefügt
# Batch 111: 20 Chunks hinzugefügt
# Batch 112: 20 Chunks hinzugefügt
# Batch 113: 20 Chunks hinzugefügt
# Batch 114: 20 Chunks hinzugefügt
# Batch 115: 20 Chunks hinzugefügt
# Batch 116: 20 Chunks hinzugefügt
# Batch 117: 20 Chunks hinzugefügt
# Batch 118: 20 Chunks hinzugefügt
# Batch 119: 20 Chunks hinzugefügt
# Batch 120: 20 Chunks hinzugefügt
# Batch 121: 20 Chunks hinzugefügt
# Batch 122: 20 Chunks hinzugefügt
# Batch 123: 20 Chunks hinzugefügt
# Batch 124: 20 Chunks hinzugefügt
# Batch 125: 20 Chunks hinzugefügt
# Batch 126: 20 Chunks hinzugefügt
# Batch 127: 20 Chunks hinzugefügt
# Batch 128: 20 Chunks hinzugefügt
# Batch 129: 20 Chunks hinzugefügt
# Batch 130: 20 Chunks hinzugefügt
# Batch 131: 20 Chunks hinzugefügt
# Batch 132: 20 Chunks hinzugefügt
# Batch 133: 20 Chunks hinzugefügt
# Batch 134: 20 Chunks hinzugefügt
# Batch 135: 20 Chunks hinzugefügt
# Batch 136: 20 Chunks hinzugefügt
# Batch 137: 20 Chunks hinzugefügt
# Batch 138: 20 Chunks hinzugefügt
# Batch 139: 20 Chunks hinzugefügt
# Batch 140: 20 Chunks hinzugefügt
# Batch 141: 20 Chunks hinzugefügt
# Batch 142: 20 Chunks hinzugefügt
# Batch 143: 20 Chunks hinzugefügt
# Batch 144: 20 Chunks hinzugefügt
# Batch 145: 20 Chunks hinzugefügt
# Batch 146: 20 Chunks hinzugefügt
# Batch 147: 20 Chunks hinzugefügt
# Batch 148: 20 Chunks hinzugefügt
# Batch 149: 20 Chunks hinzugefügt
# Batch 150: 20 Chunks hinzugefügt
# Batch 151: 20 Chunks hinzugefügt
# Batch 152: 20 Chunks hinzugefügt
# Batch 153: 20 Chunks hinzugefügt
# Batch 154: 20 Chunks hinzugefügt
# Batch 155: 20 Chunks hinzugefügt
# Batch 156: 20 Chunks hinzugefügt
# Batch 157: 20 Chunks hinzugefügt
# Batch 158: 20 Chunks hinzugefügt
# Batch 159: 20 Chunks hinzugefügt
# Batch 160: 20 Chunks hinzugefügt
# Batch 161: 20 Chunks hinzugefügt
# Batch 162: 20 Chunks hinzugefügt
# Batch 163: 20 Chunks hinzugefügt
# Batch 164: 20 Chunks hinzugefügt
# Batch 165: 20 Chunks hinzugefügt
# Batch 166: 20 Chunks hinzugefügt
# Batch 167: 20 Chunks hinzugefügt
# Batch 168: 20 Chunks hinzugefügt
# Batch 169: 20 Chunks hinzugefügt
# Batch 170: 20 Chunks hinzugefügt
# Batch 171: 20 Chunks hinzugefügt
# Batch 172: 20 Chunks hinzugefügt
# Batch 173: 20 Chunks hinzugefügt
# Batch 174: 20 Chunks hinzugefügt
# Batch 175: 20 Chunks hinzugefügt
# Batch 176: 20 Chunks hinzugefügt
# Batch 177: 20 Chunks hinzugefügt
# Batch 178: 20 Chunks hinzugefügt
# Batch 179: 20 Chunks hinzugefügt
# Batch 180: 20 Chunks hinzugefügt
# Batch 181: 20 Chunks hinzugefügt
# Batch 182: 20 Chunks hinzugefügt
# Batch 183: 20 Chunks hinzugefügt
# Batch 184: 20 Chunks hinzugefügt
# Batch 185: 20 Chunks hinzugefügt
# Batch 186: 20 Chunks hinzugefügt
# Batch 187: 20 Chunks hinzugefügt
# Batch 188: 20 Chunks hinzugefügt
# Batch 189: 20 Chunks hinzugefügt
# Batch 190: 20 Chunks hinzugefügt
# Batch 191: 20 Chunks hinzugefügt
# Batch 192: 20 Chunks hinzugefügt
# Batch 193: 20 Chunks hinzugefügt
# Batch 194: 20 Chunks hinzugefügt
# Batch 195: 20 Chunks hinzugefügt
# Batch 196: 20 Chunks hinzugefügt
# Batch 197: 20 Chunks hinzugefügt
# Batch 198: 20 Chunks hinzugefügt
# Batch 199: 20 Chunks hinzugefügt
# Batch 200: 20 Chunks hinzugefügt
# Batch 201: 20 Chunks hinzugefügt
# Batch 202: 20 Chunks hinzugefügt
# Batch 203: 20 Chunks hinzugefügt
# Batch 204: 20 Chunks hinzugefügt
# Batch 205: 20 Chunks hinzugefügt
# Batch 206: 20 Chunks hinzugefügt
# Batch 207: 20 Chunks hinzugefügt
# Batch 208: 20 Chunks hinzugefügt
# Batch 209: 20 Chunks hinzugefügt
# Batch 210: 20 Chunks hinzugefügt
# Batch 211: 20 Chunks hinzugefügt
# Batch 212: 20 Chunks hinzugefügt
# Batch 213: 20 Chunks hinzugefügt
# Batch 214: 20 Chunks hinzugefügt
# Batch 215: 20 Chunks hinzugefügt
# Batch 216: 20 Chunks hinzugefügt
# Batch 217: 20 Chunks hinzugefügt
# Batch 218: 20 Chunks hinzugefügt
# Batch 219: 20 Chunks hinzugefügt
# Batch 220: 20 Chunks hinzugefügt
# Batch 221: 20 Chunks hinzugefügt
# Batch 222: 20 Chunks hinzugefügt
# Batch 223: 20 Chunks hinzugefügt
# Batch 224: 20 Chunks hinzugefügt
# Batch 225: 20 Chunks hinzugefügt
# Batch 226: 20 Chunks hinzugefügt
# Batch 227: 20 Chunks hinzugefügt
# Batch 228: 20 Chunks hinzugefügt
# Batch 229: 20 Chunks hinzugefügt
# Batch 230: 20 Chunks hinzugefügt
# Batch 231: 20 Chunks hinzugefügt
# Batch 232: 20 Chunks hinzugefügt
# Batch 233: 20 Chunks hinzugefügt
# Batch 234: 20 Chunks hinzugefügt
# Batch 235: 20 Chunks hinzugefügt
# Batch 236: 20 Chunks hinzugefügt
# Batch 237: 20 Chunks hinzugefügt
# Batch 238: 20 Chunks hinzugefügt
# Batch 239: 20 Chunks hinzugefügt
# Batch 240: 20 Chunks hinzugefügt
# Batch 241: 20 Chunks hinzugefügt
# Batch 242: 20 Chunks hinzugefügt
# Batch 243: 20 Chunks hinzugefügt
# Batch 244: 20 Chunks hinzugefügt
# Batch 245: 20 Chunks hinzugefügt
# Batch 246: 20 Chunks hinzugefügt
# Batch 247: 20 Chunks hinzugefügt
# Batch 248: 20 Chunks hinzugefügt
# Batch 249: 20 Chunks hinzugefügt
# Batch 250: 20 Chunks hinzugefügt
# Batch 251: 20 Chunks hinzugefügt
# Batch 252: 20 Chunks hinzugefügt
# Batch 253: 20 Chunks hinzugefügt
# Batch 254: 20 Chunks hinzugefügt
# Batch 255: 20 Chunks hinzugefügt
# Batch 256: 20 Chunks hinzugefügt
# Batch 257: 20 Chunks hinzugefügt
# Batch 258: 20 Chunks hinzugefügt
# Batch 259: 20 Chunks hinzugefügt
# Batch 260: 20 Chunks hinzugefügt
# Batch 261: 20 Chunks hinzugefügt
# Batch 262: 20 Chunks hinzugefügt
# Batch 263: 20 Chunks hinzugefügt
# Batch 264: 20 Chunks hinzugefügt
# Batch 265: 20 Chunks hinzugefügt
# Batch 266: 20 Chunks hinzugefügt
# Batch 267: 20 Chunks hinzugefügt
# Batch 268: 20 Chunks hinzugefügt
# Batch 269: 20 Chunks hinzugefügt
# Batch 270: 20 Chunks hinzugefügt
# Batch 271: 20 Chunks hinzugefügt
# Batch 272: 20 Chunks hinzugefügt
# Batch 273: 20 Chunks hinzugefügt
# Batch 274: 20 Chunks hinzugefügt
# Batch 275: 20 Chunks hinzugefügt
# Batch 276: 20 Chunks hinzugefügt
# Batch 277: 20 Chunks hinzugefügt
# Batch 278: 20 Chunks hinzugefügt
# Batch 279: 20 Chunks hinzugefügt
# Batch 280: 20 Chunks hinzugefügt
# Batch 281: 20 Chunks hinzugefügt
# Batch 282: 20 Chunks hinzugefügt
# Batch 283: 20 Chunks hinzugefügt
# Batch 284: 20 Chunks hinzugefügt
# Batch 285: 20 Chunks hinzugefügt
# Batch 286: 20 Chunks hinzugefügt
# Batch 287: 20 Chunks hinzugefügt
# Batch 288: 20 Chunks hinzugefügt
# Batch 289: 20 Chunks hinzugefügt
# Batch 290: 20 Chunks hinzugefügt
# Batch 291: 20 Chunks hinzugefügt
# Batch 292: 20 Chunks hinzugefügt
# Batch 293: 20 Chunks hinzugefügt
# Batch 294: 20 Chunks hinzugefügt
# Batch 295: 20 Chunks hinzugefügt
# Batch 296: 20 Chunks hinzugefügt
# Batch 297: 20 Chunks hinzugefügt
# Batch 298: 20 Chunks hinzugefügt
# Batch 299: 20 Chunks hinzugefügt
# Batch 300: 20 Chunks hinzugefügt
# Batch 301: 20 Chunks hinzugefügt
# Batch 302: 20 Chunks hinzugefügt
# Batch 303: 20 Chunks hinzugefügt
# Batch 304: 20 Chunks hinzugefügt
# Batch 305: 20 Chunks hinzugefügt
# Batch 306: 20 Chunks hinzugefügt
# Batch 307: 20 Chunks hinzugefügt
# Batch 308: 20 Chunks hinzugefügt
# Batch 309: 20 Chunks hinzugefügt
# Batch 310: 20 Chunks hinzugefügt
# Batch 311: 20 Chunks hinzugefügt
# Batch 312: 20 Chunks hinzugefügt
# Batch 313: 20 Chunks hinzugefügt
# Batch 314: 20 Chunks hinzugefügt
# Batch 315: 20 Chunks hinzugefügt
# Batch 316: 20 Chunks hinzugefügt
# Batch 317: 20 Chunks hinzugefügt
# Batch 318: 20 Chunks hinzugefügt
# Batch 319: 20 Chunks hinzugefügt
# Batch 320: 14 Chunks hinzugefügt
# /Users/husazwerg/code/gitlab.fhnw.ch/gruppen_arbeit/npr_fs25/MC1/src/Chroma_Embedding_Pipeline.py:167: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   vector_store.persist()
# Gespeichert unter: ./chroma_recchar_800_cosine_ada-002
# Created DB: recchar_800_cosine_ada-002
# Processing config: recchar_800_cosine_3-large
# 6394 Chunks erzeugt.
# Batch 1: 20 Chunks hinzugefügt
# Batch 2: 20 Chunks hinzugefügt
# Batch 3: 20 Chunks hinzugefügt
# Batch 4: 20 Chunks hinzugefügt
# Batch 5: 20 Chunks hinzugefügt
# Batch 6: 20 Chunks hinzugefügt
# Batch 7: 20 Chunks hinzugefügt
# Batch 8: 20 Chunks hinzugefügt
# Batch 9: 20 Chunks hinzugefügt
# Batch 10: 20 Chunks hinzugefügt
# Batch 11: 20 Chunks hinzugefügt
# Batch 12: 20 Chunks hinzugefügt
# Batch 13: 20 Chunks hinzugefügt
# Batch 14: 20 Chunks hinzugefügt
# Batch 15: 20 Chunks hinzugefügt
# Batch 16: 20 Chunks hinzugefügt
# Batch 17: 20 Chunks hinzugefügt
# Batch 18: 20 Chunks hinzugefügt
# Batch 19: 20 Chunks hinzugefügt
# Batch 20: 20 Chunks hinzugefügt
# Batch 21: 20 Chunks hinzugefügt
# Batch 22: 20 Chunks hinzugefügt
# Batch 23: 20 Chunks hinzugefügt
# Batch 24: 20 Chunks hinzugefügt
# Batch 25: 20 Chunks hinzugefügt
# Batch 26: 20 Chunks hinzugefügt
# Batch 27: 20 Chunks hinzugefügt
# Batch 28: 20 Chunks hinzugefügt
# Batch 29: 20 Chunks hinzugefügt
# Batch 30: 20 Chunks hinzugefügt
# Batch 31: 20 Chunks hinzugefügt
# Batch 32: 20 Chunks hinzugefügt
# Batch 33: 20 Chunks hinzugefügt
# Batch 34: 20 Chunks hinzugefügt
# Batch 35: 20 Chunks hinzugefügt
# Batch 36: 20 Chunks hinzugefügt
# Batch 37: 20 Chunks hinzugefügt
# Batch 38: 20 Chunks hinzugefügt
# Batch 39: 20 Chunks hinzugefügt
# Batch 40: 20 Chunks hinzugefügt
# Batch 41: 20 Chunks hinzugefügt
# Batch 42: 20 Chunks hinzugefügt
# Batch 43: 20 Chunks hinzugefügt
# Batch 44: 20 Chunks hinzugefügt
# Batch 45: 20 Chunks hinzugefügt
# Batch 46: 20 Chunks hinzugefügt
# Batch 47: 20 Chunks hinzugefügt
# Batch 48: 20 Chunks hinzugefügt
# Batch 49: 20 Chunks hinzugefügt
# Batch 50: 20 Chunks hinzugefügt
# Batch 51: 20 Chunks hinzugefügt
# Batch 52: 20 Chunks hinzugefügt
# Batch 53: 20 Chunks hinzugefügt
# Batch 54: 20 Chunks hinzugefügt
# Batch 55: 20 Chunks hinzugefügt
# Batch 56: 20 Chunks hinzugefügt
# Batch 57: 20 Chunks hinzugefügt
# Batch 58: 20 Chunks hinzugefügt
# Batch 59: 20 Chunks hinzugefügt
# Batch 60: 20 Chunks hinzugefügt
# Batch 61: 20 Chunks hinzugefügt
# Batch 62: 20 Chunks hinzugefügt
# Batch 63: 20 Chunks hinzugefügt
# Batch 64: 20 Chunks hinzugefügt
# Batch 65: 20 Chunks hinzugefügt
# Batch 66: 20 Chunks hinzugefügt
# Batch 67: 20 Chunks hinzugefügt
# Batch 68: 20 Chunks hinzugefügt
# Batch 69: 20 Chunks hinzugefügt
# Batch 70: 20 Chunks hinzugefügt
# Batch 71: 20 Chunks hinzugefügt
# Batch 72: 20 Chunks hinzugefügt
# Batch 73: 20 Chunks hinzugefügt
# Batch 74: 20 Chunks hinzugefügt
# Batch 75: 20 Chunks hinzugefügt
# Batch 76: 20 Chunks hinzugefügt
# Batch 77: 20 Chunks hinzugefügt
# Batch 78: 20 Chunks hinzugefügt
# Batch 79: 20 Chunks hinzugefügt
# Batch 80: 20 Chunks hinzugefügt
# Batch 81: 20 Chunks hinzugefügt
# Batch 82: 20 Chunks hinzugefügt
# Batch 83: 20 Chunks hinzugefügt
# Batch 84: 20 Chunks hinzugefügt
# Batch 85: 20 Chunks hinzugefügt
# Batch 86: 20 Chunks hinzugefügt
# Batch 87: 20 Chunks hinzugefügt
# Batch 88: 20 Chunks hinzugefügt
# Batch 89: 20 Chunks hinzugefügt
# Batch 90: 20 Chunks hinzugefügt
# Batch 91: 20 Chunks hinzugefügt
# Batch 92: 20 Chunks hinzugefügt
# Batch 93: 20 Chunks hinzugefügt
# Batch 94: 20 Chunks hinzugefügt
# Batch 95: 20 Chunks hinzugefügt
# Batch 96: 20 Chunks hinzugefügt
# Batch 97: 20 Chunks hinzugefügt
# Batch 98: 20 Chunks hinzugefügt
# Batch 99: 20 Chunks hinzugefügt
# Batch 100: 20 Chunks hinzugefügt
# Batch 101: 20 Chunks hinzugefügt
# Batch 102: 20 Chunks hinzugefügt
# Batch 103: 20 Chunks hinzugefügt
# Batch 104: 20 Chunks hinzugefügt
# Batch 105: 20 Chunks hinzugefügt
# Batch 106: 20 Chunks hinzugefügt
# Batch 107: 20 Chunks hinzugefügt
# Batch 108: 20 Chunks hinzugefügt
# Batch 109: 20 Chunks hinzugefügt
# Batch 110: 20 Chunks hinzugefügt
# Batch 111: 20 Chunks hinzugefügt
# Batch 112: 20 Chunks hinzugefügt
# Batch 113: 20 Chunks hinzugefügt
# Batch 114: 20 Chunks hinzugefügt
# Batch 115: 20 Chunks hinzugefügt
# Batch 116: 20 Chunks hinzugefügt
# Batch 117: 20 Chunks hinzugefügt
# Batch 118: 20 Chunks hinzugefügt
# Batch 119: 20 Chunks hinzugefügt
# Batch 120: 20 Chunks hinzugefügt
# Batch 121: 20 Chunks hinzugefügt
# Batch 122: 20 Chunks hinzugefügt
# Batch 123: 20 Chunks hinzugefügt
# Batch 124: 20 Chunks hinzugefügt
# Batch 125: 20 Chunks hinzugefügt
# Batch 126: 20 Chunks hinzugefügt
# Batch 127: 20 Chunks hinzugefügt
# Batch 128: 20 Chunks hinzugefügt
# Batch 129: 20 Chunks hinzugefügt
# Batch 130: 20 Chunks hinzugefügt
# Batch 131: 20 Chunks hinzugefügt
# Batch 132: 20 Chunks hinzugefügt
# Batch 133: 20 Chunks hinzugefügt
# Batch 134: 20 Chunks hinzugefügt
# Batch 135: 20 Chunks hinzugefügt
# Batch 136: 20 Chunks hinzugefügt
# Batch 137: 20 Chunks hinzugefügt
# Batch 138: 20 Chunks hinzugefügt
# Batch 139: 20 Chunks hinzugefügt
# Batch 140: 20 Chunks hinzugefügt
# Batch 141: 20 Chunks hinzugefügt
# Batch 142: 20 Chunks hinzugefügt
# Batch 143: 20 Chunks hinzugefügt
# Batch 144: 20 Chunks hinzugefügt
# Batch 145: 20 Chunks hinzugefügt
# Batch 146: 20 Chunks hinzugefügt
# Batch 147: 20 Chunks hinzugefügt
# Batch 148: 20 Chunks hinzugefügt
# Batch 149: 20 Chunks hinzugefügt
# Batch 150: 20 Chunks hinzugefügt
# Batch 151: 20 Chunks hinzugefügt
# Batch 152: 20 Chunks hinzugefügt
# Batch 153: 20 Chunks hinzugefügt
# Batch 154: 20 Chunks hinzugefügt
# Batch 155: 20 Chunks hinzugefügt
# Batch 156: 20 Chunks hinzugefügt
# Batch 157: 20 Chunks hinzugefügt
# Batch 158: 20 Chunks hinzugefügt
# Batch 159: 20 Chunks hinzugefügt
# Batch 160: 20 Chunks hinzugefügt
# Batch 161: 20 Chunks hinzugefügt
# Batch 162: 20 Chunks hinzugefügt
# Batch 163: 20 Chunks hinzugefügt
# Batch 164: 20 Chunks hinzugefügt
# Batch 165: 20 Chunks hinzugefügt
# Batch 166: 20 Chunks hinzugefügt
# Batch 167: 20 Chunks hinzugefügt
# Batch 168: 20 Chunks hinzugefügt
# Batch 169: 20 Chunks hinzugefügt
# Batch 170: 20 Chunks hinzugefügt
# Batch 171: 20 Chunks hinzugefügt
# Batch 172: 20 Chunks hinzugefügt
# Batch 173: 20 Chunks hinzugefügt
# Batch 174: 20 Chunks hinzugefügt
# Batch 175: 20 Chunks hinzugefügt
# Batch 176: 20 Chunks hinzugefügt
# Batch 177: 20 Chunks hinzugefügt
# Batch 178: 20 Chunks hinzugefügt
# Batch 179: 20 Chunks hinzugefügt
# Batch 180: 20 Chunks hinzugefügt
# Batch 181: 20 Chunks hinzugefügt
# Batch 182: 20 Chunks hinzugefügt
# Batch 183: 20 Chunks hinzugefügt
# Batch 184: 20 Chunks hinzugefügt
# Batch 185: 20 Chunks hinzugefügt
# Batch 186: 20 Chunks hinzugefügt
# Batch 187: 20 Chunks hinzugefügt
# Batch 188: 20 Chunks hinzugefügt
# Batch 189: 20 Chunks hinzugefügt
# Batch 190: 20 Chunks hinzugefügt
# Batch 191: 20 Chunks hinzugefügt
# Batch 192: 20 Chunks hinzugefügt
# Batch 193: 20 Chunks hinzugefügt
# Batch 194: 20 Chunks hinzugefügt
# Batch 195: 20 Chunks hinzugefügt
# Batch 196: 20 Chunks hinzugefügt
# Batch 197: 20 Chunks hinzugefügt
# Batch 198: 20 Chunks hinzugefügt
# Batch 199: 20 Chunks hinzugefügt
# Batch 200: 20 Chunks hinzugefügt
# Batch 201: 20 Chunks hinzugefügt
# Batch 202: 20 Chunks hinzugefügt
# Batch 203: 20 Chunks hinzugefügt
# Batch 204: 20 Chunks hinzugefügt
# Batch 205: 20 Chunks hinzugefügt
# Batch 206: 20 Chunks hinzugefügt
# Batch 207: 20 Chunks hinzugefügt
# Batch 208: 20 Chunks hinzugefügt
# Batch 209: 20 Chunks hinzugefügt
# Batch 210: 20 Chunks hinzugefügt
# Batch 211: 20 Chunks hinzugefügt
# Batch 212: 20 Chunks hinzugefügt
# Batch 213: 20 Chunks hinzugefügt
# Batch 214: 20 Chunks hinzugefügt
# Batch 215: 20 Chunks hinzugefügt
# Batch 216: 20 Chunks hinzugefügt
# Batch 217: 20 Chunks hinzugefügt
# Batch 218: 20 Chunks hinzugefügt
# Batch 219: 20 Chunks hinzugefügt
# Batch 220: 20 Chunks hinzugefügt
# Batch 221: 20 Chunks hinzugefügt
# Batch 222: 20 Chunks hinzugefügt
# Batch 223: 20 Chunks hinzugefügt
# Batch 224: 20 Chunks hinzugefügt
# Batch 225: 20 Chunks hinzugefügt
# Batch 226: 20 Chunks hinzugefügt
# Batch 227: 20 Chunks hinzugefügt
# Batch 228: 20 Chunks hinzugefügt
# Batch 229: 20 Chunks hinzugefügt
# Batch 230: 20 Chunks hinzugefügt
# Batch 231: 20 Chunks hinzugefügt
# Batch 232: 20 Chunks hinzugefügt
# Batch 233: 20 Chunks hinzugefügt
# Batch 234: 20 Chunks hinzugefügt
# Batch 235: 20 Chunks hinzugefügt
# Batch 236: 20 Chunks hinzugefügt
# Batch 237: 20 Chunks hinzugefügt
# Batch 238: 20 Chunks hinzugefügt
# Batch 239: 20 Chunks hinzugefügt
# Batch 240: 20 Chunks hinzugefügt
# Batch 241: 20 Chunks hinzugefügt
# Batch 242: 20 Chunks hinzugefügt
# Batch 243: 20 Chunks hinzugefügt
# Batch 244: 20 Chunks hinzugefügt
# Batch 245: 20 Chunks hinzugefügt
# Batch 246: 20 Chunks hinzugefügt
# Batch 247: 20 Chunks hinzugefügt
# Batch 248: 20 Chunks hinzugefügt
# Batch 249: 20 Chunks hinzugefügt
# Batch 250: 20 Chunks hinzugefügt
# Batch 251: 20 Chunks hinzugefügt
# Batch 252: 20 Chunks hinzugefügt
# Batch 253: 20 Chunks hinzugefügt
# Batch 254: 20 Chunks hinzugefügt
# Batch 255: 20 Chunks hinzugefügt
# Batch 256: 20 Chunks hinzugefügt
# Batch 257: 20 Chunks hinzugefügt
# Batch 258: 20 Chunks hinzugefügt
# Batch 259: 20 Chunks hinzugefügt
# Batch 260: 20 Chunks hinzugefügt
# Batch 261: 20 Chunks hinzugefügt
# Batch 262: 20 Chunks hinzugefügt
# Batch 263: 20 Chunks hinzugefügt
# Batch 264: 20 Chunks hinzugefügt
# Batch 265: 20 Chunks hinzugefügt
# Batch 266: 20 Chunks hinzugefügt
# Batch 267: 20 Chunks hinzugefügt
# Batch 268: 20 Chunks hinzugefügt
# Batch 269: 20 Chunks hinzugefügt
# Batch 270: 20 Chunks hinzugefügt
# Batch 271: 20 Chunks hinzugefügt
# Batch 272: 20 Chunks hinzugefügt
# Batch 273: 20 Chunks hinzugefügt
# Batch 274: 20 Chunks hinzugefügt
# Batch 275: 20 Chunks hinzugefügt
# Batch 276: 20 Chunks hinzugefügt
# Batch 277: 20 Chunks hinzugefügt
# Batch 278: 20 Chunks hinzugefügt
# Batch 279: 20 Chunks hinzugefügt
# Batch 280: 20 Chunks hinzugefügt
# Batch 281: 20 Chunks hinzugefügt
# Batch 282: 20 Chunks hinzugefügt
# Batch 283: 20 Chunks hinzugefügt
# Batch 284: 20 Chunks hinzugefügt
# Batch 285: 20 Chunks hinzugefügt
# Batch 286: 20 Chunks hinzugefügt
# Batch 287: 20 Chunks hinzugefügt
# Batch 288: 20 Chunks hinzugefügt
# Batch 289: 20 Chunks hinzugefügt
# Batch 290: 20 Chunks hinzugefügt
# Batch 291: 20 Chunks hinzugefügt
# Batch 292: 20 Chunks hinzugefügt
# Batch 293: 20 Chunks hinzugefügt
# Batch 294: 20 Chunks hinzugefügt
# Batch 295: 20 Chunks hinzugefügt
# Batch 296: 20 Chunks hinzugefügt
# Batch 297: 20 Chunks hinzugefügt
# Batch 298: 20 Chunks hinzugefügt
# Batch 299: 20 Chunks hinzugefügt
# Batch 300: 20 Chunks hinzugefügt
# Batch 301: 20 Chunks hinzugefügt
# Batch 302: 20 Chunks hinzugefügt
# Batch 303: 20 Chunks hinzugefügt
# Batch 304: 20 Chunks hinzugefügt
# Batch 305: 20 Chunks hinzugefügt
# Batch 306: 20 Chunks hinzugefügt
# Batch 307: 20 Chunks hinzugefügt
# Batch 308: 20 Chunks hinzugefügt
# Batch 309: 20 Chunks hinzugefügt
# Batch 310: 20 Chunks hinzugefügt
# Batch 311: 20 Chunks hinzugefügt
# Batch 312: 20 Chunks hinzugefügt
# Batch 313: 20 Chunks hinzugefügt
# Batch 314: 20 Chunks hinzugefügt
# Batch 315: 20 Chunks hinzugefügt
# Batch 316: 20 Chunks hinzugefügt
# Batch 317: 20 Chunks hinzugefügt
# Batch 318: 20 Chunks hinzugefügt
# Batch 319: 20 Chunks hinzugefügt
# Batch 320: 14 Chunks hinzugefügt
# Gespeichert unter: ./chroma_recchar_800_cosine_3-large
# Created DB: recchar_800_cosine_3-large
# Processing config: recchar_800_l2_ada-002
# 6394 Chunks erzeugt.
# Batch 1: 20 Chunks hinzugefügt
# Batch 2: 20 Chunks hinzugefügt
# Batch 3: 20 Chunks hinzugefügt
# Batch 4: 20 Chunks hinzugefügt
# Batch 5: 20 Chunks hinzugefügt
# Batch 6: 20 Chunks hinzugefügt
# Batch 7: 20 Chunks hinzugefügt
# Batch 8: 20 Chunks hinzugefügt
# Batch 9: 20 Chunks hinzugefügt
# Batch 10: 20 Chunks hinzugefügt
# Batch 11: 20 Chunks hinzugefügt
# Batch 12: 20 Chunks hinzugefügt
# Batch 13: 20 Chunks hinzugefügt
# Batch 14: 20 Chunks hinzugefügt
# Batch 15: 20 Chunks hinzugefügt
# Batch 16: 20 Chunks hinzugefügt
# Batch 17: 20 Chunks hinzugefügt
# Batch 18: 20 Chunks hinzugefügt
# Batch 19: 20 Chunks hinzugefügt
# Batch 20: 20 Chunks hinzugefügt
# Batch 21: 20 Chunks hinzugefügt
# Batch 22: 20 Chunks hinzugefügt
# Batch 23: 20 Chunks hinzugefügt
# Batch 24: 20 Chunks hinzugefügt
# Batch 25: 20 Chunks hinzugefügt
# Batch 26: 20 Chunks hinzugefügt
# Batch 27: 20 Chunks hinzugefügt
# Batch 28: 20 Chunks hinzugefügt
# Batch 29: 20 Chunks hinzugefügt
# Batch 30: 20 Chunks hinzugefügt
# Batch 31: 20 Chunks hinzugefügt
# Batch 32: 20 Chunks hinzugefügt
# Batch 33: 20 Chunks hinzugefügt
# Batch 34: 20 Chunks hinzugefügt
# Batch 35: 20 Chunks hinzugefügt
# Batch 36: 20 Chunks hinzugefügt
# Batch 37: 20 Chunks hinzugefügt
# Batch 38: 20 Chunks hinzugefügt
# Batch 39: 20 Chunks hinzugefügt
# Batch 40: 20 Chunks hinzugefügt
# Batch 41: 20 Chunks hinzugefügt
# Batch 42: 20 Chunks hinzugefügt
# Batch 43: 20 Chunks hinzugefügt
# Batch 44: 20 Chunks hinzugefügt
# Batch 45: 20 Chunks hinzugefügt
# Batch 46: 20 Chunks hinzugefügt
# Batch 47: 20 Chunks hinzugefügt
# Batch 48: 20 Chunks hinzugefügt
# Batch 49: 20 Chunks hinzugefügt
# Batch 50: 20 Chunks hinzugefügt
# Batch 51: 20 Chunks hinzugefügt
# Batch 52: 20 Chunks hinzugefügt
# Batch 53: 20 Chunks hinzugefügt
# Batch 54: 20 Chunks hinzugefügt
# Batch 55: 20 Chunks hinzugefügt
# Batch 56: 20 Chunks hinzugefügt
# Batch 57: 20 Chunks hinzugefügt
# Batch 58: 20 Chunks hinzugefügt
# Batch 59: 20 Chunks hinzugefügt
# Batch 60: 20 Chunks hinzugefügt
# Batch 61: 20 Chunks hinzugefügt
# Batch 62: 20 Chunks hinzugefügt
# Batch 63: 20 Chunks hinzugefügt
# Batch 64: 20 Chunks hinzugefügt
# Batch 65: 20 Chunks hinzugefügt
# Batch 66: 20 Chunks hinzugefügt
# Batch 67: 20 Chunks hinzugefügt
# Batch 68: 20 Chunks hinzugefügt
# Batch 69: 20 Chunks hinzugefügt
# Batch 70: 20 Chunks hinzugefügt
# Batch 71: 20 Chunks hinzugefügt
# Batch 72: 20 Chunks hinzugefügt
# Batch 73: 20 Chunks hinzugefügt
# Batch 74: 20 Chunks hinzugefügt
# Batch 75: 20 Chunks hinzugefügt
# Batch 76: 20 Chunks hinzugefügt
# Batch 77: 20 Chunks hinzugefügt
# Batch 78: 20 Chunks hinzugefügt
# Batch 79: 20 Chunks hinzugefügt
# Batch 80: 20 Chunks hinzugefügt
# Batch 81: 20 Chunks hinzugefügt
# Batch 82: 20 Chunks hinzugefügt
# Batch 83: 20 Chunks hinzugefügt
# Batch 84: 20 Chunks hinzugefügt
# Batch 85: 20 Chunks hinzugefügt
# Batch 86: 20 Chunks hinzugefügt
# Batch 87: 20 Chunks hinzugefügt
# Batch 88: 20 Chunks hinzugefügt
# Batch 89: 20 Chunks hinzugefügt
# Batch 90: 20 Chunks hinzugefügt
# Batch 91: 20 Chunks hinzugefügt
# Batch 92: 20 Chunks hinzugefügt
# Batch 93: 20 Chunks hinzugefügt
# Batch 94: 20 Chunks hinzugefügt
# Batch 95: 20 Chunks hinzugefügt
# Batch 96: 20 Chunks hinzugefügt
# Batch 97: 20 Chunks hinzugefügt
# Batch 98: 20 Chunks hinzugefügt
# Batch 99: 20 Chunks hinzugefügt
# Batch 100: 20 Chunks hinzugefügt
# Batch 101: 20 Chunks hinzugefügt
# Batch 102: 20 Chunks hinzugefügt
# Batch 103: 20 Chunks hinzugefügt
# Batch 104: 20 Chunks hinzugefügt
# Batch 105: 20 Chunks hinzugefügt
# Batch 106: 20 Chunks hinzugefügt
# Batch 107: 20 Chunks hinzugefügt
# Batch 108: 20 Chunks hinzugefügt
# Batch 109: 20 Chunks hinzugefügt
# Batch 110: 20 Chunks hinzugefügt
# Batch 111: 20 Chunks hinzugefügt
# Batch 112: 20 Chunks hinzugefügt
# Batch 113: 20 Chunks hinzugefügt
# Batch 114: 20 Chunks hinzugefügt
# Batch 115: 20 Chunks hinzugefügt
# Batch 116: 20 Chunks hinzugefügt
# Batch 117: 20 Chunks hinzugefügt
# Batch 118: 20 Chunks hinzugefügt
# Batch 119: 20 Chunks hinzugefügt
# Batch 120: 20 Chunks hinzugefügt
# Batch 121: 20 Chunks hinzugefügt
# Batch 122: 20 Chunks hinzugefügt
# Batch 123: 20 Chunks hinzugefügt
# Batch 124: 20 Chunks hinzugefügt
# Batch 125: 20 Chunks hinzugefügt
# Batch 126: 20 Chunks hinzugefügt
# Batch 127: 20 Chunks hinzugefügt
# Batch 128: 20 Chunks hinzugefügt
# Batch 129: 20 Chunks hinzugefügt
# Batch 130: 20 Chunks hinzugefügt
# Batch 131: 20 Chunks hinzugefügt
# Batch 132: 20 Chunks hinzugefügt
# Batch 133: 20 Chunks hinzugefügt
# Batch 134: 20 Chunks hinzugefügt
# Batch 135: 20 Chunks hinzugefügt
# Batch 136: 20 Chunks hinzugefügt
# Batch 137: 20 Chunks hinzugefügt
# Batch 138: 20 Chunks hinzugefügt
# Batch 139: 20 Chunks hinzugefügt
# Batch 140: 20 Chunks hinzugefügt
# Batch 141: 20 Chunks hinzugefügt
# Batch 142: 20 Chunks hinzugefügt
# Batch 143: 20 Chunks hinzugefügt
# Batch 144: 20 Chunks hinzugefügt
# Batch 145: 20 Chunks hinzugefügt
# Batch 146: 20 Chunks hinzugefügt
# Batch 147: 20 Chunks hinzugefügt
# Batch 148: 20 Chunks hinzugefügt
# Batch 149: 20 Chunks hinzugefügt
# Batch 150: 20 Chunks hinzugefügt
# Batch 151: 20 Chunks hinzugefügt
# Batch 152: 20 Chunks hinzugefügt
# Batch 153: 20 Chunks hinzugefügt
# Batch 154: 20 Chunks hinzugefügt
# Batch 155: 20 Chunks hinzugefügt
# Batch 156: 20 Chunks hinzugefügt
# Batch 157: 20 Chunks hinzugefügt
# Batch 158: 20 Chunks hinzugefügt
# Batch 159: 20 Chunks hinzugefügt
# Batch 160: 20 Chunks hinzugefügt
# Batch 161: 20 Chunks hinzugefügt
# Batch 162: 20 Chunks hinzugefügt
# Batch 163: 20 Chunks hinzugefügt
# Batch 164: 20 Chunks hinzugefügt
# Batch 165: 20 Chunks hinzugefügt
# Batch 166: 20 Chunks hinzugefügt
# Batch 167: 20 Chunks hinzugefügt
# Batch 168: 20 Chunks hinzugefügt
# Batch 169: 20 Chunks hinzugefügt
# Batch 170: 20 Chunks hinzugefügt
# Batch 171: 20 Chunks hinzugefügt
# Batch 172: 20 Chunks hinzugefügt
# Batch 173: 20 Chunks hinzugefügt
# Batch 174: 20 Chunks hinzugefügt
# Batch 175: 20 Chunks hinzugefügt
# Batch 176: 20 Chunks hinzugefügt
# Batch 177: 20 Chunks hinzugefügt
# Batch 178: 20 Chunks hinzugefügt
# Batch 179: 20 Chunks hinzugefügt
# Batch 180: 20 Chunks hinzugefügt
# Batch 181: 20 Chunks hinzugefügt
# Batch 182: 20 Chunks hinzugefügt
# Batch 183: 20 Chunks hinzugefügt
# Batch 184: 20 Chunks hinzugefügt
# Batch 185: 20 Chunks hinzugefügt
# Batch 186: 20 Chunks hinzugefügt
# Batch 187: 20 Chunks hinzugefügt
# Batch 188: 20 Chunks hinzugefügt
# Batch 189: 20 Chunks hinzugefügt
# Batch 190: 20 Chunks hinzugefügt
# Batch 191: 20 Chunks hinzugefügt
# Batch 192: 20 Chunks hinzugefügt
# Batch 193: 20 Chunks hinzugefügt
# Batch 194: 20 Chunks hinzugefügt
# Batch 195: 20 Chunks hinzugefügt
# Batch 196: 20 Chunks hinzugefügt
# Batch 197: 20 Chunks hinzugefügt
# Batch 198: 20 Chunks hinzugefügt
# Batch 199: 20 Chunks hinzugefügt
# Batch 200: 20 Chunks hinzugefügt
# Batch 201: 20 Chunks hinzugefügt
# Batch 202: 20 Chunks hinzugefügt
# Batch 203: 20 Chunks hinzugefügt
# Batch 204: 20 Chunks hinzugefügt
# Batch 205: 20 Chunks hinzugefügt
# Batch 206: 20 Chunks hinzugefügt
# Batch 207: 20 Chunks hinzugefügt
# Batch 208: 20 Chunks hinzugefügt
# Batch 209: 20 Chunks hinzugefügt
# Batch 210: 20 Chunks hinzugefügt
# Batch 211: 20 Chunks hinzugefügt
# Batch 212: 20 Chunks hinzugefügt
# Batch 213: 20 Chunks hinzugefügt
# Batch 214: 20 Chunks hinzugefügt
# Batch 215: 20 Chunks hinzugefügt
# Batch 216: 20 Chunks hinzugefügt
# Batch 217: 20 Chunks hinzugefügt
# Batch 218: 20 Chunks hinzugefügt
# Batch 219: 20 Chunks hinzugefügt
# Batch 220: 20 Chunks hinzugefügt
# Batch 221: 20 Chunks hinzugefügt
# Batch 222: 20 Chunks hinzugefügt
# Batch 223: 20 Chunks hinzugefügt
# Batch 224: 20 Chunks hinzugefügt
# Batch 225: 20 Chunks hinzugefügt
# Batch 226: 20 Chunks hinzugefügt
# Batch 227: 20 Chunks hinzugefügt
# Batch 228: 20 Chunks hinzugefügt
# Batch 229: 20 Chunks hinzugefügt
# Batch 230: 20 Chunks hinzugefügt
# Batch 231: 20 Chunks hinzugefügt
# Batch 232: 20 Chunks hinzugefügt
# Batch 233: 20 Chunks hinzugefügt
# Batch 234: 20 Chunks hinzugefügt
# Batch 235: 20 Chunks hinzugefügt
# Batch 236: 20 Chunks hinzugefügt
# Batch 237: 20 Chunks hinzugefügt
# Batch 238: 20 Chunks hinzugefügt
# Batch 239: 20 Chunks hinzugefügt
# Batch 240: 20 Chunks hinzugefügt
# Batch 241: 20 Chunks hinzugefügt
# Batch 242: 20 Chunks hinzugefügt
# Batch 243: 20 Chunks hinzugefügt
# Batch 244: 20 Chunks hinzugefügt
# Batch 245: 20 Chunks hinzugefügt
# Batch 246: 20 Chunks hinzugefügt
# Batch 247: 20 Chunks hinzugefügt
# Batch 248: 20 Chunks hinzugefügt
# Batch 249: 20 Chunks hinzugefügt
# Batch 250: 20 Chunks hinzugefügt
# Batch 251: 20 Chunks hinzugefügt
# Batch 252: 20 Chunks hinzugefügt
# Batch 253: 20 Chunks hinzugefügt
# Batch 254: 20 Chunks hinzugefügt
# Batch 255: 20 Chunks hinzugefügt
# Batch 256: 20 Chunks hinzugefügt
# Batch 257: 20 Chunks hinzugefügt
# Batch 258: 20 Chunks hinzugefügt
# Batch 259: 20 Chunks hinzugefügt
# Batch 260: 20 Chunks hinzugefügt
# Batch 261: 20 Chunks hinzugefügt
# Batch 262: 20 Chunks hinzugefügt
# Batch 263: 20 Chunks hinzugefügt
# Batch 264: 20 Chunks hinzugefügt
# Batch 265: 20 Chunks hinzugefügt
# Batch 266: 20 Chunks hinzugefügt
# Batch 267: 20 Chunks hinzugefügt
# Batch 268: 20 Chunks hinzugefügt
# Batch 269: 20 Chunks hinzugefügt
# Batch 270: 20 Chunks hinzugefügt
# Batch 271: 20 Chunks hinzugefügt
# Batch 272: 20 Chunks hinzugefügt
# Batch 273: 20 Chunks hinzugefügt
# Batch 274: 20 Chunks hinzugefügt
# Batch 275: 20 Chunks hinzugefügt
# Batch 276: 20 Chunks hinzugefügt
# Batch 277: 20 Chunks hinzugefügt
# Batch 278: 20 Chunks hinzugefügt
# Batch 279: 20 Chunks hinzugefügt
# Batch 280: 20 Chunks hinzugefügt
# Batch 281: 20 Chunks hinzugefügt
# Batch 282: 20 Chunks hinzugefügt
# Batch 283: 20 Chunks hinzugefügt
# Batch 284: 20 Chunks hinzugefügt
# Batch 285: 20 Chunks hinzugefügt
# Batch 286: 20 Chunks hinzugefügt
# Batch 287: 20 Chunks hinzugefügt
# Batch 288: 20 Chunks hinzugefügt
# Batch 289: 20 Chunks hinzugefügt
# Batch 290: 20 Chunks hinzugefügt
# Batch 291: 20 Chunks hinzugefügt
# Batch 292: 20 Chunks hinzugefügt
# Batch 293: 20 Chunks hinzugefügt
# Batch 294: 20 Chunks hinzugefügt
# Batch 295: 20 Chunks hinzugefügt
# Batch 296: 20 Chunks hinzugefügt
# Batch 297: 20 Chunks hinzugefügt
# Batch 298: 20 Chunks hinzugefügt
# Batch 299: 20 Chunks hinzugefügt
# Batch 300: 20 Chunks hinzugefügt
# Batch 301: 20 Chunks hinzugefügt
# Batch 302: 20 Chunks hinzugefügt
# Batch 303: 20 Chunks hinzugefügt
# Batch 304: 20 Chunks hinzugefügt
# Batch 305: 20 Chunks hinzugefügt
# Batch 306: 20 Chunks hinzugefügt
# Batch 307: 20 Chunks hinzugefügt
# Batch 308: 20 Chunks hinzugefügt
# Batch 309: 20 Chunks hinzugefügt
# Batch 310: 20 Chunks hinzugefügt
# Batch 311: 20 Chunks hinzugefügt
# Batch 312: 20 Chunks hinzugefügt
# Batch 313: 20 Chunks hinzugefügt
# Batch 314: 20 Chunks hinzugefügt
# Batch 315: 20 Chunks hinzugefügt
# Batch 316: 20 Chunks hinzugefügt
# Batch 317: 20 Chunks hinzugefügt
# Batch 318: 20 Chunks hinzugefügt
# Batch 319: 20 Chunks hinzugefügt
# Batch 320: 14 Chunks hinzugefügt
# Gespeichert unter: ./chroma_recchar_800_l2_ada-002
# Created DB: recchar_800_l2_ada-002
# Processing config: recchar_800_l2_3-large
# 6394 Chunks erzeugt.
# Batch 1: 20 Chunks hinzugefügt
# Batch 2: 20 Chunks hinzugefügt
# Batch 3: 20 Chunks hinzugefügt
# Batch 4: 20 Chunks hinzugefügt
# Batch 5: 20 Chunks hinzugefügt
# Batch 6: 20 Chunks hinzugefügt
# Batch 7: 20 Chunks hinzugefügt
# Batch 8: 20 Chunks hinzugefügt
# Batch 9: 20 Chunks hinzugefügt
# Batch 10: 20 Chunks hinzugefügt
# Batch 11: 20 Chunks hinzugefügt
# Batch 12: 20 Chunks hinzugefügt
# Batch 13: 20 Chunks hinzugefügt
# Batch 14: 20 Chunks hinzugefügt
# Batch 15: 20 Chunks hinzugefügt
# Batch 16: 20 Chunks hinzugefügt
# Batch 17: 20 Chunks hinzugefügt
# Batch 18: 20 Chunks hinzugefügt
# Batch 19: 20 Chunks hinzugefügt
# Batch 20: 20 Chunks hinzugefügt
# Batch 21: 20 Chunks hinzugefügt
# Batch 22: 20 Chunks hinzugefügt
# Batch 23: 20 Chunks hinzugefügt
# Batch 24: 20 Chunks hinzugefügt
# Batch 25: 20 Chunks hinzugefügt
# Batch 26: 20 Chunks hinzugefügt
# Batch 27: 20 Chunks hinzugefügt
# Batch 28: 20 Chunks hinzugefügt
# Batch 29: 20 Chunks hinzugefügt
# Batch 30: 20 Chunks hinzugefügt
# Batch 31: 20 Chunks hinzugefügt
# Batch 32: 20 Chunks hinzugefügt
# Batch 33: 20 Chunks hinzugefügt
# Batch 34: 20 Chunks hinzugefügt
# Batch 35: 20 Chunks hinzugefügt
# Batch 36: 20 Chunks hinzugefügt
# Batch 37: 20 Chunks hinzugefügt
# Batch 38: 20 Chunks hinzugefügt
# Batch 39: 20 Chunks hinzugefügt
# Batch 40: 20 Chunks hinzugefügt
# Batch 41: 20 Chunks hinzugefügt
# Batch 42: 20 Chunks hinzugefügt
# Batch 43: 20 Chunks hinzugefügt
# Batch 44: 20 Chunks hinzugefügt
# Batch 45: 20 Chunks hinzugefügt
# Batch 46: 20 Chunks hinzugefügt
# Batch 47: 20 Chunks hinzugefügt
# Batch 48: 20 Chunks hinzugefügt
# Batch 49: 20 Chunks hinzugefügt
# Batch 50: 20 Chunks hinzugefügt
# Batch 51: 20 Chunks hinzugefügt
# Batch 52: 20 Chunks hinzugefügt
# Batch 53: 20 Chunks hinzugefügt
# Batch 54: 20 Chunks hinzugefügt
# Batch 55: 20 Chunks hinzugefügt
# Batch 56: 20 Chunks hinzugefügt
# Batch 57: 20 Chunks hinzugefügt
# Batch 58: 20 Chunks hinzugefügt
# Batch 59: 20 Chunks hinzugefügt
# Batch 60: 20 Chunks hinzugefügt
# Batch 61: 20 Chunks hinzugefügt
# Batch 62: 20 Chunks hinzugefügt
# Batch 63: 20 Chunks hinzugefügt
# Batch 64: 20 Chunks hinzugefügt
# Batch 65: 20 Chunks hinzugefügt
# Batch 66: 20 Chunks hinzugefügt
# Batch 67: 20 Chunks hinzugefügt
# Batch 68: 20 Chunks hinzugefügt
# Batch 69: 20 Chunks hinzugefügt
# Batch 70: 20 Chunks hinzugefügt
# Batch 71: 20 Chunks hinzugefügt
# Batch 72: 20 Chunks hinzugefügt
# Batch 73: 20 Chunks hinzugefügt
# Batch 74: 20 Chunks hinzugefügt
# Batch 75: 20 Chunks hinzugefügt
# Batch 76: 20 Chunks hinzugefügt
# Batch 77: 20 Chunks hinzugefügt
# Batch 78: 20 Chunks hinzugefügt
# Batch 79: 20 Chunks hinzugefügt
# Batch 80: 20 Chunks hinzugefügt
# Batch 81: 20 Chunks hinzugefügt
# Batch 82: 20 Chunks hinzugefügt
# Batch 83: 20 Chunks hinzugefügt
# Batch 84: 20 Chunks hinzugefügt
# Batch 85: 20 Chunks hinzugefügt
# Batch 86: 20 Chunks hinzugefügt
# Batch 87: 20 Chunks hinzugefügt
# Batch 88: 20 Chunks hinzugefügt
# Batch 89: 20 Chunks hinzugefügt
# Batch 90: 20 Chunks hinzugefügt
# Batch 91: 20 Chunks hinzugefügt
# Batch 92: 20 Chunks hinzugefügt
# Batch 93: 20 Chunks hinzugefügt
# Batch 94: 20 Chunks hinzugefügt
# Batch 95: 20 Chunks hinzugefügt
# Batch 96: 20 Chunks hinzugefügt
# Batch 97: 20 Chunks hinzugefügt
# Batch 98: 20 Chunks hinzugefügt
# Batch 99: 20 Chunks hinzugefügt
# Batch 100: 20 Chunks hinzugefügt
# Batch 101: 20 Chunks hinzugefügt
# Batch 102: 20 Chunks hinzugefügt
# Batch 103: 20 Chunks hinzugefügt
# Batch 104: 20 Chunks hinzugefügt
# Batch 105: 20 Chunks hinzugefügt
# Batch 106: 20 Chunks hinzugefügt
# Batch 107: 20 Chunks hinzugefügt
# Batch 108: 20 Chunks hinzugefügt
# Batch 109: 20 Chunks hinzugefügt
# Batch 110: 20 Chunks hinzugefügt
# Batch 111: 20 Chunks hinzugefügt
# Batch 112: 20 Chunks hinzugefügt
# Batch 113: 20 Chunks hinzugefügt
# Batch 114: 20 Chunks hinzugefügt
# Batch 115: 20 Chunks hinzugefügt
# Batch 116: 20 Chunks hinzugefügt
# Batch 117: 20 Chunks hinzugefügt
# Batch 118: 20 Chunks hinzugefügt
# Batch 119: 20 Chunks hinzugefügt
# Batch 120: 20 Chunks hinzugefügt
# Batch 121: 20 Chunks hinzugefügt
# Batch 122: 20 Chunks hinzugefügt
# Batch 123: 20 Chunks hinzugefügt
# Batch 124: 20 Chunks hinzugefügt
# Batch 125: 20 Chunks hinzugefügt
# Batch 126: 20 Chunks hinzugefügt
# Batch 127: 20 Chunks hinzugefügt
# Batch 128: 20 Chunks hinzugefügt
# Batch 129: 20 Chunks hinzugefügt
# Batch 130: 20 Chunks hinzugefügt
# Batch 131: 20 Chunks hinzugefügt
# Batch 132: 20 Chunks hinzugefügt
# Batch 133: 20 Chunks hinzugefügt
# Batch 134: 20 Chunks hinzugefügt
# Batch 135: 20 Chunks hinzugefügt
# Batch 136: 20 Chunks hinzugefügt
# Batch 137: 20 Chunks hinzugefügt
# Batch 138: 20 Chunks hinzugefügt
# Batch 139: 20 Chunks hinzugefügt
# Batch 140: 20 Chunks hinzugefügt
# Batch 141: 20 Chunks hinzugefügt
# Batch 142: 20 Chunks hinzugefügt
# Batch 143: 20 Chunks hinzugefügt
# Batch 144: 20 Chunks hinzugefügt
# Batch 145: 20 Chunks hinzugefügt
# Batch 146: 20 Chunks hinzugefügt
# Batch 147: 20 Chunks hinzugefügt
# Batch 148: 20 Chunks hinzugefügt
# Batch 149: 20 Chunks hinzugefügt
# Batch 150: 20 Chunks hinzugefügt
# Batch 151: 20 Chunks hinzugefügt
# Batch 152: 20 Chunks hinzugefügt
# Batch 153: 20 Chunks hinzugefügt
# Batch 154: 20 Chunks hinzugefügt
# Batch 155: 20 Chunks hinzugefügt
# Batch 156: 20 Chunks hinzugefügt
# Batch 157: 20 Chunks hinzugefügt
# Batch 158: 20 Chunks hinzugefügt
# Batch 159: 20 Chunks hinzugefügt
# Batch 160: 20 Chunks hinzugefügt
# Batch 161: 20 Chunks hinzugefügt
# Batch 162: 20 Chunks hinzugefügt
# Batch 163: 20 Chunks hinzugefügt
# Batch 164: 20 Chunks hinzugefügt
# Batch 165: 20 Chunks hinzugefügt
# Batch 166: 20 Chunks hinzugefügt
# Batch 167: 20 Chunks hinzugefügt
# Batch 168: 20 Chunks hinzugefügt
# Batch 169: 20 Chunks hinzugefügt
# Batch 170: 20 Chunks hinzugefügt
# Batch 171: 20 Chunks hinzugefügt
# Batch 172: 20 Chunks hinzugefügt
# Batch 173: 20 Chunks hinzugefügt
# Batch 174: 20 Chunks hinzugefügt
# Batch 175: 20 Chunks hinzugefügt
# Batch 176: 20 Chunks hinzugefügt
# Batch 177: 20 Chunks hinzugefügt
# Batch 178: 20 Chunks hinzugefügt
# Batch 179: 20 Chunks hinzugefügt
# Batch 180: 20 Chunks hinzugefügt
# Batch 181: 20 Chunks hinzugefügt
# Batch 182: 20 Chunks hinzugefügt
# Batch 183: 20 Chunks hinzugefügt
# Batch 184: 20 Chunks hinzugefügt
# Batch 185: 20 Chunks hinzugefügt
# Batch 186: 20 Chunks hinzugefügt
# Batch 187: 20 Chunks hinzugefügt
# Batch 188: 20 Chunks hinzugefügt
# Batch 189: 20 Chunks hinzugefügt
# Batch 190: 20 Chunks hinzugefügt
# Batch 191: 20 Chunks hinzugefügt
# Batch 192: 20 Chunks hinzugefügt
# Batch 193: 20 Chunks hinzugefügt
# Batch 194: 20 Chunks hinzugefügt
# Batch 195: 20 Chunks hinzugefügt
# Batch 196: 20 Chunks hinzugefügt
# Batch 197: 20 Chunks hinzugefügt
# Batch 198: 20 Chunks hinzugefügt
# Batch 199: 20 Chunks hinzugefügt
# Batch 200: 20 Chunks hinzugefügt
# Batch 201: 20 Chunks hinzugefügt
# Batch 202: 20 Chunks hinzugefügt
# Batch 203: 20 Chunks hinzugefügt
# Batch 204: 20 Chunks hinzugefügt
# Batch 205: 20 Chunks hinzugefügt
# Batch 206: 20 Chunks hinzugefügt
# Batch 207: 20 Chunks hinzugefügt
# Batch 208: 20 Chunks hinzugefügt
# Batch 209: 20 Chunks hinzugefügt
# Batch 210: 20 Chunks hinzugefügt
# Batch 211: 20 Chunks hinzugefügt
# Batch 212: 20 Chunks hinzugefügt
# Batch 213: 20 Chunks hinzugefügt
# Batch 214: 20 Chunks hinzugefügt
# Batch 215: 20 Chunks hinzugefügt
# Batch 216: 20 Chunks hinzugefügt
# Batch 217: 20 Chunks hinzugefügt
# Batch 218: 20 Chunks hinzugefügt
# Batch 219: 20 Chunks hinzugefügt
# Batch 220: 20 Chunks hinzugefügt
# Batch 221: 20 Chunks hinzugefügt
# Batch 222: 20 Chunks hinzugefügt
# Batch 223: 20 Chunks hinzugefügt
# Batch 224: 20 Chunks hinzugefügt
# Batch 225: 20 Chunks hinzugefügt
# Batch 226: 20 Chunks hinzugefügt
# Batch 227: 20 Chunks hinzugefügt
# Batch 228: 20 Chunks hinzugefügt
# Batch 229: 20 Chunks hinzugefügt
# Batch 230: 20 Chunks hinzugefügt
# Batch 231: 20 Chunks hinzugefügt
# Batch 232: 20 Chunks hinzugefügt
# Batch 233: 20 Chunks hinzugefügt
# Batch 234: 20 Chunks hinzugefügt
# Batch 235: 20 Chunks hinzugefügt
# Batch 236: 20 Chunks hinzugefügt
# Batch 237: 20 Chunks hinzugefügt
# Batch 238: 20 Chunks hinzugefügt
# Batch 239: 20 Chunks hinzugefügt
# Batch 240: 20 Chunks hinzugefügt
# Batch 241: 20 Chunks hinzugefügt
# Batch 242: 20 Chunks hinzugefügt
# Batch 243: 20 Chunks hinzugefügt
# Batch 244: 20 Chunks hinzugefügt
# Batch 245: 20 Chunks hinzugefügt
# Batch 246: 20 Chunks hinzugefügt
# Batch 247: 20 Chunks hinzugefügt
# Batch 248: 20 Chunks hinzugefügt
# Batch 249: 20 Chunks hinzugefügt
# Batch 250: 20 Chunks hinzugefügt
# Batch 251: 20 Chunks hinzugefügt
# Batch 252: 20 Chunks hinzugefügt
# Batch 253: 20 Chunks hinzugefügt
# Batch 254: 20 Chunks hinzugefügt
# Batch 255: 20 Chunks hinzugefügt
# Batch 256: 20 Chunks hinzugefügt
# Batch 257: 20 Chunks hinzugefügt
# Batch 258: 20 Chunks hinzugefügt
# Batch 259: 20 Chunks hinzugefügt
# Batch 260: 20 Chunks hinzugefügt
# Batch 261: 20 Chunks hinzugefügt
# Batch 262: 20 Chunks hinzugefügt
# Batch 263: 20 Chunks hinzugefügt
# Batch 264: 20 Chunks hinzugefügt
# Batch 265: 20 Chunks hinzugefügt
# Batch 266: 20 Chunks hinzugefügt
# Batch 267: 20 Chunks hinzugefügt
# Batch 268: 20 Chunks hinzugefügt
# Batch 269: 20 Chunks hinzugefügt
# Batch 270: 20 Chunks hinzugefügt
# Batch 271: 20 Chunks hinzugefügt
# Batch 272: 20 Chunks hinzugefügt
# Batch 273: 20 Chunks hinzugefügt
# Batch 274: 20 Chunks hinzugefügt
# Batch 275: 20 Chunks hinzugefügt
# Batch 276: 20 Chunks hinzugefügt
# Batch 277: 20 Chunks hinzugefügt
# Batch 278: 20 Chunks hinzugefügt
# Batch 279: 20 Chunks hinzugefügt
# Batch 280: 20 Chunks hinzugefügt
# Batch 281: 20 Chunks hinzugefügt
# Batch 282: 20 Chunks hinzugefügt
# Batch 283: 20 Chunks hinzugefügt
# Batch 284: 20 Chunks hinzugefügt
# Batch 285: 20 Chunks hinzugefügt
# Batch 286: 20 Chunks hinzugefügt
# Batch 287: 20 Chunks hinzugefügt
# Batch 288: 20 Chunks hinzugefügt
# Batch 289: 20 Chunks hinzugefügt
# Batch 290: 20 Chunks hinzugefügt
# Batch 291: 20 Chunks hinzugefügt
# Batch 292: 20 Chunks hinzugefügt
# Batch 293: 20 Chunks hinzugefügt
# Batch 294: 20 Chunks hinzugefügt
# Batch 295: 20 Chunks hinzugefügt
# Batch 296: 20 Chunks hinzugefügt
# Batch 297: 20 Chunks hinzugefügt
# Batch 298: 20 Chunks hinzugefügt
# Batch 299: 20 Chunks hinzugefügt
# Batch 300: 20 Chunks hinzugefügt
# Batch 301: 20 Chunks hinzugefügt
# Batch 302: 20 Chunks hinzugefügt
# Batch 303: 20 Chunks hinzugefügt
# Batch 304: 20 Chunks hinzugefügt
# Batch 305: 20 Chunks hinzugefügt
# Batch 306: 20 Chunks hinzugefügt
# Batch 307: 20 Chunks hinzugefügt
# Batch 308: 20 Chunks hinzugefügt
# Batch 309: 20 Chunks hinzugefügt
# Batch 310: 20 Chunks hinzugefügt
# Batch 311: 20 Chunks hinzugefügt
# Batch 312: 20 Chunks hinzugefügt
# Batch 313: 20 Chunks hinzugefügt
# Batch 314: 20 Chunks hinzugefügt
# Batch 315: 20 Chunks hinzugefügt
# Batch 316: 20 Chunks hinzugefügt
# Batch 317: 20 Chunks hinzugefügt
# Batch 318: 20 Chunks hinzugefügt
# Batch 319: 20 Chunks hinzugefügt
# Batch 320: 14 Chunks hinzugefügt
# Gespeichert unter: ./chroma_recchar_800_l2_3-large
# Created DB: recchar_800_l2_3-large
# Processing config: recchar_800_ip_ada-002
# 6394 Chunks erzeugt.
# Batch 1: 20 Chunks hinzugefügt
# Batch 2: 20 Chunks hinzugefügt
# Batch 3: 20 Chunks hinzugefügt
# Batch 4: 20 Chunks hinzugefügt
# Batch 5: 20 Chunks hinzugefügt
# Batch 6: 20 Chunks hinzugefügt
# Batch 7: 20 Chunks hinzugefügt
# Batch 8: 20 Chunks hinzugefügt
# Batch 9: 20 Chunks hinzugefügt
# Batch 10: 20 Chunks hinzugefügt
# Batch 11: 20 Chunks hinzugefügt
# Batch 12: 20 Chunks hinzugefügt
# Batch 13: 20 Chunks hinzugefügt
# Batch 14: 20 Chunks hinzugefügt
# Batch 15: 20 Chunks hinzugefügt
# Batch 16: 20 Chunks hinzugefügt
# Batch 17: 20 Chunks hinzugefügt
# Batch 18: 20 Chunks hinzugefügt
# Batch 19: 20 Chunks hinzugefügt
# Batch 20: 20 Chunks hinzugefügt
# Batch 21: 20 Chunks hinzugefügt
# Batch 22: 20 Chunks hinzugefügt
# Batch 23: 20 Chunks hinzugefügt
# Batch 24: 20 Chunks hinzugefügt
# Batch 25: 20 Chunks hinzugefügt
# Batch 26: 20 Chunks hinzugefügt
# Batch 27: 20 Chunks hinzugefügt
# Batch 28: 20 Chunks hinzugefügt
# Batch 29: 20 Chunks hinzugefügt
# Batch 30: 20 Chunks hinzugefügt
# Batch 31: 20 Chunks hinzugefügt
# Batch 32: 20 Chunks hinzugefügt
# Batch 33: 20 Chunks hinzugefügt
# Batch 34: 20 Chunks hinzugefügt
# Batch 35: 20 Chunks hinzugefügt
# Batch 36: 20 Chunks hinzugefügt
# Batch 37: 20 Chunks hinzugefügt
# Batch 38: 20 Chunks hinzugefügt
# Batch 39: 20 Chunks hinzugefügt
# Batch 40: 20 Chunks hinzugefügt
# Batch 41: 20 Chunks hinzugefügt
# Batch 42: 20 Chunks hinzugefügt
# Batch 43: 20 Chunks hinzugefügt
# Batch 44: 20 Chunks hinzugefügt
# Batch 45: 20 Chunks hinzugefügt
# Batch 46: 20 Chunks hinzugefügt
# Batch 47: 20 Chunks hinzugefügt
# Batch 48: 20 Chunks hinzugefügt
# Batch 49: 20 Chunks hinzugefügt
# Batch 50: 20 Chunks hinzugefügt
# Batch 51: 20 Chunks hinzugefügt
# Batch 52: 20 Chunks hinzugefügt
# Batch 53: 20 Chunks hinzugefügt
# Batch 54: 20 Chunks hinzugefügt
# Batch 55: 20 Chunks hinzugefügt
# Batch 56: 20 Chunks hinzugefügt
# Batch 57: 20 Chunks hinzugefügt
# Batch 58: 20 Chunks hinzugefügt
# Batch 59: 20 Chunks hinzugefügt
# Batch 60: 20 Chunks hinzugefügt
# Batch 61: 20 Chunks hinzugefügt
# Batch 62: 20 Chunks hinzugefügt
# Batch 63: 20 Chunks hinzugefügt
# Batch 64: 20 Chunks hinzugefügt
# Batch 65: 20 Chunks hinzugefügt
# Batch 66: 20 Chunks hinzugefügt
# Batch 67: 20 Chunks hinzugefügt
# Batch 68: 20 Chunks hinzugefügt
# Batch 69: 20 Chunks hinzugefügt
# Batch 70: 20 Chunks hinzugefügt
# Batch 71: 20 Chunks hinzugefügt
# Batch 72: 20 Chunks hinzugefügt
# Batch 73: 20 Chunks hinzugefügt
# Batch 74: 20 Chunks hinzugefügt
# Batch 75: 20 Chunks hinzugefügt
# Batch 76: 20 Chunks hinzugefügt
# Batch 77: 20 Chunks hinzugefügt
# Batch 78: 20 Chunks hinzugefügt
# Batch 79: 20 Chunks hinzugefügt
# Batch 80: 20 Chunks hinzugefügt
# Batch 81: 20 Chunks hinzugefügt
# Batch 82: 20 Chunks hinzugefügt
# Batch 83: 20 Chunks hinzugefügt
# Batch 84: 20 Chunks hinzugefügt
# Batch 85: 20 Chunks hinzugefügt
# Batch 86: 20 Chunks hinzugefügt
# Batch 87: 20 Chunks hinzugefügt
# Batch 88: 20 Chunks hinzugefügt
# Batch 89: 20 Chunks hinzugefügt
# Batch 90: 20 Chunks hinzugefügt
# Batch 91: 20 Chunks hinzugefügt
# Batch 92: 20 Chunks hinzugefügt
# Batch 93: 20 Chunks hinzugefügt
# Batch 94: 20 Chunks hinzugefügt
# Batch 95: 20 Chunks hinzugefügt
# Batch 96: 20 Chunks hinzugefügt
# Batch 97: 20 Chunks hinzugefügt
# Batch 98: 20 Chunks hinzugefügt
# Batch 99: 20 Chunks hinzugefügt
# Batch 100: 20 Chunks hinzugefügt
# Batch 101: 20 Chunks hinzugefügt
# Batch 102: 20 Chunks hinzugefügt
# Batch 103: 20 Chunks hinzugefügt
# Batch 104: 20 Chunks hinzugefügt
# Batch 105: 20 Chunks hinzugefügt
# Batch 106: 20 Chunks hinzugefügt
# Batch 107: 20 Chunks hinzugefügt
# Batch 108: 20 Chunks hinzugefügt
# Batch 109: 20 Chunks hinzugefügt
# Batch 110: 20 Chunks hinzugefügt
# Batch 111: 20 Chunks hinzugefügt
# Batch 112: 20 Chunks hinzugefügt
# Batch 113: 20 Chunks hinzugefügt
# Batch 114: 20 Chunks hinzugefügt
# Batch 115: 20 Chunks hinzugefügt
# Batch 116: 20 Chunks hinzugefügt
# Batch 117: 20 Chunks hinzugefügt
# Batch 118: 20 Chunks hinzugefügt
# Batch 119: 20 Chunks hinzugefügt
# Batch 120: 20 Chunks hinzugefügt
# Batch 121: 20 Chunks hinzugefügt
# Batch 122: 20 Chunks hinzugefügt
# Batch 123: 20 Chunks hinzugefügt
# Batch 124: 20 Chunks hinzugefügt
# Batch 125: 20 Chunks hinzugefügt
# Batch 126: 20 Chunks hinzugefügt
# Batch 127: 20 Chunks hinzugefügt
# Batch 128: 20 Chunks hinzugefügt
# Batch 129: 20 Chunks hinzugefügt
# Batch 130: 20 Chunks hinzugefügt
# Batch 131: 20 Chunks hinzugefügt
# Batch 132: 20 Chunks hinzugefügt
# Batch 133: 20 Chunks hinzugefügt
# Batch 134: 20 Chunks hinzugefügt
# Batch 135: 20 Chunks hinzugefügt
# Batch 136: 20 Chunks hinzugefügt
# Batch 137: 20 Chunks hinzugefügt
# Batch 138: 20 Chunks hinzugefügt
# Batch 139: 20 Chunks hinzugefügt
# Batch 140: 20 Chunks hinzugefügt
# Batch 141: 20 Chunks hinzugefügt
# Batch 142: 20 Chunks hinzugefügt
# Batch 143: 20 Chunks hinzugefügt
# Batch 144: 20 Chunks hinzugefügt
# Batch 145: 20 Chunks hinzugefügt
# Batch 146: 20 Chunks hinzugefügt
# Batch 147: 20 Chunks hinzugefügt
# Batch 148: 20 Chunks hinzugefügt
# ...
# Batch 95: 20 Chunks hinzugefügt
# Batch 96: 20 Chunks hinzugefügt
# Batch 97: 20 Chunks hinzugefügt
# Batch 98: 20 Chunks hinzugefügt
# Batch 99: 20 Chunks hinzugefügt
# Batch 100: 20 Chunks hinzugefügt
# Batch 101: 20 Chunks hinzugefügt
# Batch 102: 20 Chunks hinzugefügt
# Batch 103: 20 Chunks hinzugefügt
# Batch 104: 20 Chunks hinzugefügt
# Batch 105: 20 Chunks hinzugefügt
# Batch 106: 20 Chunks hinzugefügt
# Batch 107: 20 Chunks hinzugefügt
# Batch 108: 20 Chunks hinzugefügt
# Batch 109: 20 Chunks hinzugefügt
# Batch 110: 20 Chunks hinzugefügt
# Batch 111: 20 Chunks hinzugefügt
# Batch 112: 20 Chunks hinzugefügt
# Batch 113: 20 Chunks hinzugefügt
# Batch 114: 20 Chunks hinzugefügt
# Batch 115: 20 Chunks hinzugefügt
# Batch 116: 20 Chunks hinzugefügt
# Batch 117: 20 Chunks hinzugefügt
# Batch 118: 20 Chunks hinzugefügt
# Batch 119: 20 Chunks hinzugefügt
# Batch 120: 20 Chunks hinzugefügt
# Batch 121: 20 Chunks hinzugefügt
# Batch 122: 20 Chunks hinzugefügt
# Batch 123: 20 Chunks hinzugefügt
# Batch 124: 20 Chunks hinzugefügt
# Batch 125: 20 Chunks hinzugefügt
# Batch 126: 20 Chunks hinzugefügt
# Batch 127: 20 Chunks hinzugefügt
# Batch 128: 20 Chunks hinzugefügt
# Batch 129: 20 Chunks hinzugefügt
# Batch 130: 20 Chunks hinzugefügt
# Batch 131: 20 Chunks hinzugefügt
# Batch 132: 20 Chunks hinzugefügt
# Batch 133: 20 Chunks hinzugefügt
# Batch 134: 20 Chunks hinzugefügt
# Batch 135: 20 Chunks hinzugefügt
# Batch 136: 20 Chunks hinzugefügt
# Batch 137: 20 Chunks hinzugefügt
# Batch 138: 20 Chunks hinzugefügt
# Batch 139: 20 Chunks hinzugefügt
# Batch 140: 20 Chunks hinzugefügt
# Batch 141: 20 Chunks hinzugefügt
# Batch 142: 20 Chunks hinzugefügt
# Batch 143: 20 Chunks hinzugefügt
# Batch 144: 20 Chunks hinzugefügt
# Batch 145: 20 Chunks hinzugefügt
# Batch 146: 20 Chunks hinzugefügt
# Batch 147: 20 Chunks hinzugefügt
# Batch 148: 20 Chunks hinzugefügt
# Batch 149: 20 Chunks hinzugefügt
# Batch 150: 20 Chunks hinzugefügt
# Batch 151: 20 Chunks hinzugefügt
# Batch 152: 20 Chunks hinzugefügt
# Batch 153: 20 Chunks hinzugefügt
# Batch 154: 20 Chunks hinzugefügt
# Batch 155: 20 Chunks hinzugefügt
# Batch 156: 20 Chunks hinzugefügt
# Batch 157: 20 Chunks hinzugefügt
# Batch 158: 20 Chunks hinzugefügt
# Batch 159: 20 Chunks hinzugefügt
# Batch 160: 20 Chunks hinzugefügt
# Batch 161: 20 Chunks hinzugefügt
# Batch 162: 20 Chunks hinzugefügt
# Batch 163: 20 Chunks hinzugefügt
# Batch 164: 20 Chunks hinzugefügt
# Batch 165: 20 Chunks hinzugefügt
# Batch 166: 20 Chunks hinzugefügt
# Batch 167: 20 Chunks hinzugefügt
# Batch 168: 20 Chunks hinzugefügt
# Batch 169: 20 Chunks hinzugefügt
# Batch 170: 20 Chunks hinzugefügt
# Batch 171: 20 Chunks hinzugefügt
# Batch 172: 20 Chunks hinzugefügt
# Batch 173: 20 Chunks hinzugefügt
# Batch 174: 20 Chunks hinzugefügt
# Batch 175: 20 Chunks hinzugefügt
# Batch 176: 20 Chunks hinzugefügt
# Batch 177: 20 Chunks hinzugefügt
# Batch 178: 20 Chunks hinzugefügt
# Batch 179: 20 Chunks hinzugefügt
# Batch 180: 20 Chunks hinzugefügt
# Batch 181: 20 Chunks hinzugefügt
# Batch 182: 20 Chunks hinzugefügt
# Batch 183: 20 Chunks hinzugefügt
# Batch 184: 20 Chunks hinzugefügt
# Batch 185: 20 Chunks hinzugefügt
# Batch 186: 20 Chunks hinzugefügt
# Batch 187: 20 Chunks hinzugefügt
# Batch 188: 20 Chunks hinzugefügt
# Batch 189: 20 Chunks hinzugefügt
# Batch 190: 20 Chunks hinzugefügt
# Batch 191: 7 Chunks hinzugefügt
# Gespeichert unter: ./chroma_senttrans_200_l2_3-large
# Created DB: senttrans_200_l2_3-large
# Processing config: senttrans_200_ip_ada-002
# 3807 Chunks erzeugt.
# Batch 1: 20 Chunks hinzugefügt
# Batch 2: 20 Chunks hinzugefügt
# Batch 3: 20 Chunks hinzugefügt
# Batch 4: 20 Chunks hinzugefügt
# Batch 5: 20 Chunks hinzugefügt
# Batch 6: 20 Chunks hinzugefügt
# Batch 7: 20 Chunks hinzugefügt
# Batch 8: 20 Chunks hinzugefügt
# Batch 9: 20 Chunks hinzugefügt
# Batch 10: 20 Chunks hinzugefügt
# Batch 11: 20 Chunks hinzugefügt
# Batch 12: 20 Chunks hinzugefügt
# Batch 13: 20 Chunks hinzugefügt
# Batch 14: 20 Chunks hinzugefügt
# Batch 15: 20 Chunks hinzugefügt
# Batch 16: 20 Chunks hinzugefügt
# Batch 17: 20 Chunks hinzugefügt
# Batch 18: 20 Chunks hinzugefügt
# Batch 19: 20 Chunks hinzugefügt
# Batch 20: 20 Chunks hinzugefügt
# Batch 21: 20 Chunks hinzugefügt
# Batch 22: 20 Chunks hinzugefügt
# Batch 23: 20 Chunks hinzugefügt
# Batch 24: 20 Chunks hinzugefügt
# Batch 25: 20 Chunks hinzugefügt
# Batch 26: 20 Chunks hinzugefügt
# Batch 27: 20 Chunks hinzugefügt
# Batch 28: 20 Chunks hinzugefügt
# Batch 29: 20 Chunks hinzugefügt
# Batch 30: 20 Chunks hinzugefügt
# Batch 31: 20 Chunks hinzugefügt
# Batch 32: 20 Chunks hinzugefügt
# Batch 33: 20 Chunks hinzugefügt
# Batch 34: 20 Chunks hinzugefügt
# Batch 35: 20 Chunks hinzugefügt
# Batch 36: 20 Chunks hinzugefügt
# Batch 37: 20 Chunks hinzugefügt
# Batch 38: 20 Chunks hinzugefügt
# Batch 39: 20 Chunks hinzugefügt
# Batch 40: 20 Chunks hinzugefügt
# Batch 41: 20 Chunks hinzugefügt
# Batch 42: 20 Chunks hinzugefügt
# Batch 43: 20 Chunks hinzugefügt
# Batch 44: 20 Chunks hinzugefügt
# Batch 45: 20 Chunks hinzugefügt
# Batch 46: 20 Chunks hinzugefügt
# Batch 47: 20 Chunks hinzugefügt
# Batch 48: 20 Chunks hinzugefügt
# Batch 49: 20 Chunks hinzugefügt
# Batch 50: 20 Chunks hinzugefügt
# Batch 51: 20 Chunks hinzugefügt
# Batch 52: 20 Chunks hinzugefügt
# Batch 53: 20 Chunks hinzugefügt
# Batch 54: 20 Chunks hinzugefügt
# Batch 55: 20 Chunks hinzugefügt
# Batch 56: 20 Chunks hinzugefügt
# Batch 57: 20 Chunks hinzugefügt
# Batch 58: 20 Chunks hinzugefügt
# Batch 59: 20 Chunks hinzugefügt
# Batch 60: 20 Chunks hinzugefügt
# Batch 61: 20 Chunks hinzugefügt
# Batch 62: 20 Chunks hinzugefügt
# Batch 63: 20 Chunks hinzugefügt
# Batch 64: 20 Chunks hinzugefügt
# Batch 65: 20 Chunks hinzugefügt
# Batch 66: 20 Chunks hinzugefügt
# Batch 67: 20 Chunks hinzugefügt
# Batch 68: 20 Chunks hinzugefügt
# Batch 69: 20 Chunks hinzugefügt
# Batch 70: 20 Chunks hinzugefügt
# Batch 71: 20 Chunks hinzugefügt
# Batch 72: 20 Chunks hinzugefügt
# Batch 73: 20 Chunks hinzugefügt
# Batch 74: 20 Chunks hinzugefügt
# Batch 75: 20 Chunks hinzugefügt
# Batch 76: 20 Chunks hinzugefügt
# Batch 77: 20 Chunks hinzugefügt
# Batch 78: 20 Chunks hinzugefügt
# Batch 79: 20 Chunks hinzugefügt
# Batch 80: 20 Chunks hinzugefügt
# Batch 81: 20 Chunks hinzugefügt
# Batch 82: 20 Chunks hinzugefügt
# Batch 83: 20 Chunks hinzugefügt
# Batch 84: 20 Chunks hinzugefügt
# Batch 85: 20 Chunks hinzugefügt
# Batch 86: 20 Chunks hinzugefügt
# Batch 87: 20 Chunks hinzugefügt
# Batch 88: 20 Chunks hinzugefügt
# Batch 89: 20 Chunks hinzugefügt
# Batch 90: 20 Chunks hinzugefügt
# Batch 91: 20 Chunks hinzugefügt
# Batch 92: 20 Chunks hinzugefügt
# Batch 93: 20 Chunks hinzugefügt
# Batch 94: 20 Chunks hinzugefügt
# Batch 95: 20 Chunks hinzugefügt
# Batch 96: 20 Chunks hinzugefügt
# Batch 97: 20 Chunks hinzugefügt
# Batch 98: 20 Chunks hinzugefügt
# Batch 99: 20 Chunks hinzugefügt
# Batch 100: 20 Chunks hinzugefügt
# Batch 101: 20 Chunks hinzugefügt
# Batch 102: 20 Chunks hinzugefügt
# Batch 103: 20 Chunks hinzugefügt
# Batch 104: 20 Chunks hinzugefügt
# Batch 105: 20 Chunks hinzugefügt
# Batch 106: 20 Chunks hinzugefügt
# Batch 107: 20 Chunks hinzugefügt
# Batch 108: 20 Chunks hinzugefügt
# Batch 109: 20 Chunks hinzugefügt
# Batch 110: 20 Chunks hinzugefügt
# Batch 111: 20 Chunks hinzugefügt
# Batch 112: 20 Chunks hinzugefügt
# Batch 113: 20 Chunks hinzugefügt
# Batch 114: 20 Chunks hinzugefügt
# Batch 115: 20 Chunks hinzugefügt
# Batch 116: 20 Chunks hinzugefügt
# Batch 117: 20 Chunks hinzugefügt
# Batch 118: 20 Chunks hinzugefügt
# Batch 119: 20 Chunks hinzugefügt
# Batch 120: 20 Chunks hinzugefügt
# Batch 121: 20 Chunks hinzugefügt
# Batch 122: 20 Chunks hinzugefügt
# Batch 123: 20 Chunks hinzugefügt
# Batch 124: 20 Chunks hinzugefügt
# Batch 125: 20 Chunks hinzugefügt
# Batch 126: 20 Chunks hinzugefügt
# Batch 127: 20 Chunks hinzugefügt
# Batch 128: 20 Chunks hinzugefügt
# Batch 129: 20 Chunks hinzugefügt
# Batch 130: 20 Chunks hinzugefügt
# Batch 131: 20 Chunks hinzugefügt
# Batch 132: 20 Chunks hinzugefügt
# Batch 133: 20 Chunks hinzugefügt
# Batch 134: 20 Chunks hinzugefügt
# Batch 135: 20 Chunks hinzugefügt
# Batch 136: 20 Chunks hinzugefügt
# Batch 137: 20 Chunks hinzugefügt
# Batch 138: 20 Chunks hinzugefügt
# Batch 139: 20 Chunks hinzugefügt
# Batch 140: 20 Chunks hinzugefügt
# Batch 141: 20 Chunks hinzugefügt
# Batch 142: 20 Chunks hinzugefügt
# Batch 143: 20 Chunks hinzugefügt
# Batch 144: 20 Chunks hinzugefügt
# Batch 145: 20 Chunks hinzugefügt
# Batch 146: 20 Chunks hinzugefügt
# Batch 147: 20 Chunks hinzugefügt
# Batch 148: 20 Chunks hinzugefügt
# Batch 149: 20 Chunks hinzugefügt
# Batch 150: 20 Chunks hinzugefügt
# Batch 151: 20 Chunks hinzugefügt
# Batch 152: 20 Chunks hinzugefügt
# Batch 153: 20 Chunks hinzugefügt
# Batch 154: 20 Chunks hinzugefügt
# Batch 155: 20 Chunks hinzugefügt
# Batch 156: 20 Chunks hinzugefügt
# Batch 157: 20 Chunks hinzugefügt
# Batch 158: 20 Chunks hinzugefügt
# Batch 159: 20 Chunks hinzugefügt
# Batch 160: 20 Chunks hinzugefügt
# Batch 161: 20 Chunks hinzugefügt
# Batch 162: 20 Chunks hinzugefügt
# Batch 163: 20 Chunks hinzugefügt
# Batch 164: 20 Chunks hinzugefügt
# Batch 165: 20 Chunks hinzugefügt
# Batch 166: 20 Chunks hinzugefügt
# Batch 167: 20 Chunks hinzugefügt
# Batch 168: 20 Chunks hinzugefügt
# Batch 169: 20 Chunks hinzugefügt
# Batch 170: 20 Chunks hinzugefügt
# Batch 171: 20 Chunks hinzugefügt
# Batch 172: 20 Chunks hinzugefügt
# Batch 173: 20 Chunks hinzugefügt
# Batch 174: 20 Chunks hinzugefügt
# Batch 175: 20 Chunks hinzugefügt
# Batch 176: 20 Chunks hinzugefügt
# Batch 177: 20 Chunks hinzugefügt
# Batch 178: 20 Chunks hinzugefügt
# Batch 179: 20 Chunks hinzugefügt
# Batch 180: 20 Chunks hinzugefügt
# Batch 181: 20 Chunks hinzugefügt
# Batch 182: 20 Chunks hinzugefügt
# Batch 183: 20 Chunks hinzugefügt
# Batch 184: 20 Chunks hinzugefügt
# Batch 185: 20 Chunks hinzugefügt
# Batch 186: 20 Chunks hinzugefügt
# Batch 187: 20 Chunks hinzugefügt
# Batch 188: 20 Chunks hinzugefügt
# Batch 189: 20 Chunks hinzugefügt
# Batch 190: 20 Chunks hinzugefügt
# Batch 191: 7 Chunks hinzugefügt
# Gespeichert unter: ./chroma_senttrans_200_ip_ada-002
# Created DB: senttrans_200_ip_ada-002
# Processing config: senttrans_200_ip_3-large
# 3807 Chunks erzeugt.
# Batch 1: 20 Chunks hinzugefügt
# Batch 2: 20 Chunks hinzugefügt
# Batch 3: 20 Chunks hinzugefügt
# Batch 4: 20 Chunks hinzugefügt
# Batch 5: 20 Chunks hinzugefügt
# Batch 6: 20 Chunks hinzugefügt
# Batch 7: 20 Chunks hinzugefügt
# Batch 8: 20 Chunks hinzugefügt
# Batch 9: 20 Chunks hinzugefügt
# Batch 10: 20 Chunks hinzugefügt
# Batch 11: 20 Chunks hinzugefügt
# Batch 12: 20 Chunks hinzugefügt
# Batch 13: 20 Chunks hinzugefügt
# Batch 14: 20 Chunks hinzugefügt
# Batch 15: 20 Chunks hinzugefügt
# Batch 16: 20 Chunks hinzugefügt
# Batch 17: 20 Chunks hinzugefügt
# Batch 18: 20 Chunks hinzugefügt
# Batch 19: 20 Chunks hinzugefügt
# Batch 20: 20 Chunks hinzugefügt
# Batch 21: 20 Chunks hinzugefügt
# Batch 22: 20 Chunks hinzugefügt
# Batch 23: 20 Chunks hinzugefügt
# Batch 24: 20 Chunks hinzugefügt
# Batch 25: 20 Chunks hinzugefügt
# Batch 26: 20 Chunks hinzugefügt
# Batch 27: 20 Chunks hinzugefügt
# Batch 28: 20 Chunks hinzugefügt
# Batch 29: 20 Chunks hinzugefügt
# Batch 30: 20 Chunks hinzugefügt
# Batch 31: 20 Chunks hinzugefügt
# Batch 32: 20 Chunks hinzugefügt
# Batch 33: 20 Chunks hinzugefügt
# Batch 34: 20 Chunks hinzugefügt
# Batch 35: 20 Chunks hinzugefügt
# Batch 36: 20 Chunks hinzugefügt
# Batch 37: 20 Chunks hinzugefügt
# Batch 38: 20 Chunks hinzugefügt
# Batch 39: 20 Chunks hinzugefügt
# Batch 40: 20 Chunks hinzugefügt
# Batch 41: 20 Chunks hinzugefügt
# Batch 42: 20 Chunks hinzugefügt
# Batch 43: 20 Chunks hinzugefügt
# Batch 44: 20 Chunks hinzugefügt
# Batch 45: 20 Chunks hinzugefügt
# Batch 46: 20 Chunks hinzugefügt
# Batch 47: 20 Chunks hinzugefügt
# Batch 48: 20 Chunks hinzugefügt
# Batch 49: 20 Chunks hinzugefügt
# Batch 50: 20 Chunks hinzugefügt
# Batch 51: 20 Chunks hinzugefügt
# Batch 52: 20 Chunks hinzugefügt
# Batch 53: 20 Chunks hinzugefügt
# Batch 54: 20 Chunks hinzugefügt
# Batch 55: 20 Chunks hinzugefügt
# Batch 56: 20 Chunks hinzugefügt
# Batch 57: 20 Chunks hinzugefügt
# Batch 58: 20 Chunks hinzugefügt
# Batch 59: 20 Chunks hinzugefügt
# Batch 60: 20 Chunks hinzugefügt
# Batch 61: 20 Chunks hinzugefügt
# Batch 62: 20 Chunks hinzugefügt
# Batch 63: 20 Chunks hinzugefügt
# Batch 64: 20 Chunks hinzugefügt
# Batch 65: 20 Chunks hinzugefügt
# Batch 66: 20 Chunks hinzugefügt
# Batch 67: 20 Chunks hinzugefügt
# Batch 68: 20 Chunks hinzugefügt
# Batch 69: 20 Chunks hinzugefügt
# Batch 70: 20 Chunks hinzugefügt
# Batch 71: 20 Chunks hinzugefügt
# Batch 72: 20 Chunks hinzugefügt
# Batch 73: 20 Chunks hinzugefügt
# Batch 74: 20 Chunks hinzugefügt
# Batch 75: 20 Chunks hinzugefügt
# Batch 76: 20 Chunks hinzugefügt
# Batch 77: 20 Chunks hinzugefügt
# Batch 78: 20 Chunks hinzugefügt
# Batch 79: 20 Chunks hinzugefügt
# Batch 80: 20 Chunks hinzugefügt
# Batch 81: 20 Chunks hinzugefügt
# Batch 82: 20 Chunks hinzugefügt
# Batch 83: 20 Chunks hinzugefügt
# Batch 84: 20 Chunks hinzugefügt
# Batch 85: 20 Chunks hinzugefügt
# Batch 86: 20 Chunks hinzugefügt
# Batch 87: 20 Chunks hinzugefügt
# Batch 88: 20 Chunks hinzugefügt
# Batch 89: 20 Chunks hinzugefügt
# Batch 90: 20 Chunks hinzugefügt
# Batch 91: 20 Chunks hinzugefügt
# Batch 92: 20 Chunks hinzugefügt
# Batch 93: 20 Chunks hinzugefügt
# Batch 94: 20 Chunks hinzugefügt
# Batch 95: 20 Chunks hinzugefügt
# Batch 96: 20 Chunks hinzugefügt
# Batch 97: 20 Chunks hinzugefügt
# Batch 98: 20 Chunks hinzugefügt
# Batch 99: 20 Chunks hinzugefügt
# Batch 100: 20 Chunks hinzugefügt
# Batch 101: 20 Chunks hinzugefügt
# Batch 102: 20 Chunks hinzugefügt
# Batch 103: 20 Chunks hinzugefügt
# Batch 104: 20 Chunks hinzugefügt
# Batch 105: 20 Chunks hinzugefügt
# Batch 106: 20 Chunks hinzugefügt
# Batch 107: 20 Chunks hinzugefügt
# Batch 108: 20 Chunks hinzugefügt
# Batch 109: 20 Chunks hinzugefügt
# Batch 110: 20 Chunks hinzugefügt
# Batch 111: 20 Chunks hinzugefügt
# Batch 112: 20 Chunks hinzugefügt
# Batch 113: 20 Chunks hinzugefügt
# Batch 114: 20 Chunks hinzugefügt
# Batch 115: 20 Chunks hinzugefügt
# Batch 116: 20 Chunks hinzugefügt
# Batch 117: 20 Chunks hinzugefügt
# Batch 118: 20 Chunks hinzugefügt
# Batch 119: 20 Chunks hinzugefügt
# Batch 120: 20 Chunks hinzugefügt
# Batch 121: 20 Chunks hinzugefügt
# Batch 122: 20 Chunks hinzugefügt
# Batch 123: 20 Chunks hinzugefügt
# Batch 124: 20 Chunks hinzugefügt
# Batch 125: 20 Chunks hinzugefügt
# Batch 126: 20 Chunks hinzugefügt
# Batch 127: 20 Chunks hinzugefügt
# Batch 128: 20 Chunks hinzugefügt
# Batch 129: 20 Chunks hinzugefügt
# Batch 130: 20 Chunks hinzugefügt
# Batch 131: 20 Chunks hinzugefügt
# Batch 132: 20 Chunks hinzugefügt
# Batch 133: 20 Chunks hinzugefügt
# Batch 134: 20 Chunks hinzugefügt
# Batch 135: 20 Chunks hinzugefügt
# Batch 136: 20 Chunks hinzugefügt
# Batch 137: 20 Chunks hinzugefügt
# Batch 138: 20 Chunks hinzugefügt
# Batch 139: 20 Chunks hinzugefügt
# Batch 140: 20 Chunks hinzugefügt
# Batch 141: 20 Chunks hinzugefügt
# Batch 142: 20 Chunks hinzugefügt
# Batch 143: 20 Chunks hinzugefügt
# Batch 144: 20 Chunks hinzugefügt
# Batch 145: 20 Chunks hinzugefügt
# Batch 146: 20 Chunks hinzugefügt
# Batch 147: 20 Chunks hinzugefügt
# Batch 148: 20 Chunks hinzugefügt
# Batch 149: 20 Chunks hinzugefügt
# Batch 150: 20 Chunks hinzugefügt
# Batch 151: 20 Chunks hinzugefügt
# Batch 152: 20 Chunks hinzugefügt
# Batch 153: 20 Chunks hinzugefügt
# Batch 154: 20 Chunks hinzugefügt
# Batch 155: 20 Chunks hinzugefügt
# Batch 156: 20 Chunks hinzugefügt
# Batch 157: 20 Chunks hinzugefügt
# Batch 158: 20 Chunks hinzugefügt
# Batch 159: 20 Chunks hinzugefügt
# Batch 160: 20 Chunks hinzugefügt
# Batch 161: 20 Chunks hinzugefügt
# Batch 162: 20 Chunks hinzugefügt
# Batch 163: 20 Chunks hinzugefügt
# Batch 164: 20 Chunks hinzugefügt
# Batch 165: 20 Chunks hinzugefügt
# Batch 166: 20 Chunks hinzugefügt
# Batch 167: 20 Chunks hinzugefügt
# Batch 168: 20 Chunks hinzugefügt
# Batch 169: 20 Chunks hinzugefügt
# Batch 170: 20 Chunks hinzugefügt
# Batch 171: 20 Chunks hinzugefügt
# Batch 172: 20 Chunks hinzugefügt
# Batch 173: 20 Chunks hinzugefügt
# Batch 174: 20 Chunks hinzugefügt
# Batch 175: 20 Chunks hinzugefügt
# Batch 176: 20 Chunks hinzugefügt
# Batch 177: 20 Chunks hinzugefügt
# Batch 178: 20 Chunks hinzugefügt
# Batch 179: 20 Chunks hinzugefügt
# Batch 180: 20 Chunks hinzugefügt
# Batch 181: 20 Chunks hinzugefügt
# Batch 182: 20 Chunks hinzugefügt
# Batch 183: 20 Chunks hinzugefügt
# Batch 184: 20 Chunks hinzugefügt
# Batch 185: 20 Chunks hinzugefügt
# Batch 186: 20 Chunks hinzugefügt
# Batch 187: 20 Chunks hinzugefügt
# Batch 188: 20 Chunks hinzugefügt
# Batch 189: 20 Chunks hinzugefügt
# Batch 190: 20 Chunks hinzugefügt
# Batch 191: 7 Chunks hinzugefügt
# Gespeichert unter: ./chroma_senttrans_200_ip_3-large
# Created DB: senttrans_200_ip_3-large
